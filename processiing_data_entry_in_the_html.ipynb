# %%
<!DOCTYPE html>
<html lang="en">

<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>

<body>

    <div style="color:blue">
        <form action="{{ url_for('predict')}}" method="post">
            <h2>Predictive analysis</h2>
            <h3>Year</h3>
            <input id="first" name="Year" type="number ">
            <h3>What is the acquisition price of the vehicule in average condition?(In usd)</h3><br><input id="second" name="MMRAcquisitionAuctionAveragePrice" required="required">
            <h3>What is the warranty cost?(In usd)</h3><br><input id="second" name="WarrantyCost" required="required">
            <h3>What is the country of the manufacturer?</h3><input id="third" name="Nationality_encoded" required="required">
                <option value='OTHER ASIAN'>OTHER ASIAN</option>
                <option value='AMERICAN'>AMERICAN</option>
                <option value='TOP LINE ASIAN'>TOP LINE ASIAN</option>
                <option value='OTHER'>OTHER</option>
            <h3>what is the model?</h3><br><input id="fourth" name="Model_encoded" required="required">
                <option value="Petrol">Petrol</option>
                <option value='MAZDA3'>MAZDA3</option>
                <option value='1500 RAM PICKUP 2WD'>1500 RAM PICKUP 2WD</option>
                <option value='STRATUS V6'>STRATUS V6</option>
                <option value='NEON'>NEON</option>
                <option value='FOCUS'>FOCUS</option>
                <option value='GALANT 4C'>GALANT 4C</option>
                <option value='SPECTRA'>SPECTRA</option>
                <option value='TAURUS'>TAURUS</option>
                <option value='FIVE HUNDRED'>FIVE HUNDRED</option>
                <option value='1500 SIERRA PICKUP 2'>1500 SIERRA PICKUP 2</option>
                <option value='F150 PICKUP 2WD V6'>F150 PICKUP 2WD V6</option>
                <option value='CARAVAN GRAND FWD V6'>CARAVAN GRAND FWD V6</option>
                <option value='ALTIMA'>ALTIMA</option>
                <option value='CAVALIER 4C'>CAVALIER 4C</option>
                <option value='TRAILBLAZER 2WD 6C'>TRAILBLAZER 2WD 6C</option>
                <option value='VUE 2WD 4C'>VUE 2WD 4C</option>
                <option value='IMPALA'>IMPALA</option>
                <option value='ENVOY XL 2WD 6C'>ENVOY XL 2WD 6C</option>
                <option value='VOYAGER FWD V6'>VOYAGER FWD V6</option>
                <option value='MONTE CARLO'>MONTE CARLO</option>
                <option value='VENTURE FWD V6'>VENTURE FWD V6</option>
                <option value='HHR'>HHR</option>
                <option value='SABLE'>SABLE</option>
                <option value='ENVOY XL 4WD 6C'>ENVOY XL 4WD 6C</option>
                <option value='DURANGO 4WD V8'>DURANGO 4WD V8</option>
                <option value='SUBURBAN 1500 2WD'>SUBURBAN 1500 2WD</option>
                <option value='EXPLORER 2WD V6'>EXPLORER 2WD V6</option>
                <option value='300'>300</option>
                <option value='MUSTANG V6'>MUSTANG V6</option>
                <option value='AVALANCHE 1500 2WD V'>AVALANCHE 1500 2WD V</option>
                <option value='WINDSTAR FWD V6'>WINDSTAR FWD V6</option>
                <option value='FREESTAR FWD V6'>FREESTAR FWD V6</option>
                <option value='SONATA V6'>SONATA V6</option>
                <option value='CALIBER'>CALIBER</option>
                <option value='SENTRA'>SENTRA</option>
                <option value='PACIFICA FWD'>PACIFICA FWD</option>
                <option value='IMPALA V6'>IMPALA V6</option>
                <option value='XTERRA 2WD V6'>XTERRA 2WD V6</option>
                <option value='COROLLA'>COROLLA</option>
                <option value='G6 V6'>G6 V6</option>
                <option value='ION'>ION</option>
                <option value='DURANGO 2WD V8'>DURANGO 2WD V8</option>
                <option value='FUSION 4C'>FUSION 4C</option>
                <option value='4 RUNNER 2WD V8'>4 RUNNER 2WD V8</option>
                <option value='GRAND PRIX'>GRAND PRIX</option>
                <option value='SEBRING V6'>SEBRING V6</option>
                <option value='FORENZA'>FORENZA</option>
                <option value='MAZDA5'>MAZDA5</option>
                <option value='LIBERTY 2WD V6'>LIBERTY 2WD V6</option>
                <option value='DAKOTA PICKUP 2WD V6'>DAKOTA PICKUP 2WD V6</option>
                <option value='TAHOE 2WD'>TAHOE 2WD</option>
                <option value='COBALT'>COBALT</option>
                <option value='EXPEDITION 2WD V8'>EXPEDITION 2WD V8</option>
                <option value='ELEMENT 2WD'>ELEMENT 2WD</option>
                <option value='SUNFIRE'>SUNFIRE</option>
                <option value='RELAY 2WD V6'>RELAY 2WD V6</option>
                <option value='FREESTYLE 2WD V6'>FREESTYLE 2WD V6</option>
                <option value='F150 PICKUP 2WD V8'>F150 PICKUP 2WD V8</option>
                <option value='TRAILBLAZER EXT 2WD'>TRAILBLAZER EXT 2WD</option>
                <option value='PT CRUISER'>PT CRUISER</option>
                <option value='TRACKER 2WD V6'>TRACKER 2WD V6</option>
                <option value='DURANGO 2WD V6'>DURANGO 2WD V6</option>
                <option value='MALIBU V6'>MALIBU V6</option>
                <option value='ALERO 4C'>ALERO 4C</option>
                <option value='TOWN & COUNTRY FWD V'>TOWN & COUNTRY FWD V</option>
                <option value='CAMRY V6'>CAMRY V6</option>
                <option value='MAGNUM V6'>MAGNUM V6</option>
                <option value='EQUINOX FWD V6'>EQUINOX FWD V6</option>
                <option value='STRATUS 4C'>STRATUS 4C</option>
                <option value='LIBERTY 2WD 4C'>LIBERTY 2WD 4C</option>
                <option value='MAZDA6'>MAZDA6</option>
                <option value='CAMRY 4C'>CAMRY 4C</option>
                <option value='FREESTYLE FWD V6'>FREESTYLE FWD V6</option>
                <option value='L SERIES'>L SERIES</option>
                <option value='RENO'>RENO</option>
                <option value='SEBRING 4C'>SEBRING 4C</option>
                <option value='SILHOUETTE'>SILHOUETTE</option>
                <option value='ESCAPE 4WD V6'>ESCAPE 4WD V6</option>
                <option value='OPTIMA 4C'>OPTIMA 4C</option>
                <option value='RANGER PICKUP 2WD V6'>RANGER PICKUP 2WD V6</option>
                <option value='G6 4C'>G6 4C</option>
                <option value='ENVOY 2WD 6C'>ENVOY 2WD 6C</option>
                <option value='ACCENT'>ACCENT</option>
                <option value='UPLANDER FWD V6'>UPLANDER FWD V6</option>
                <option value='ELANTRA'>ELANTRA</option>
                <option value='1500 SILVERADO PICKU'>1500 SILVERADO PICKU</option>
                <option value='PARK AVENUE'>PARK AVENUE</option>
                <option value='ENDEAVOR FWD'>ENDEAVOR FWD</option>
                <option value='AMANTI'>AMANTI</option>
                <option value='TUCSON 2WD 4C'>TUCSON 2WD 4C</option>
                <option value='XB'>XB</option>
                <option value='EXPLORER 4WD V6'>EXPLORER 4WD V6</option>
                <option value='ESCAPE 2WD V6'>ESCAPE 2WD V6</option>
                <option value='CARAVAN FWD V6'>CARAVAN FWD V6</option>
                <option value='TRIBUTE 2WD 4C'>TRIBUTE 2WD 4C</option>
                <option value='SONATA 4C'>SONATA 4C</option>
                <option value='RENDEZVOUS FWD'>RENDEZVOUS FWD</option>
                <option value='ACCORD 4C'>ACCORD 4C</option>
                <option value='ESCAPE 2WD 4C'>ESCAPE 2WD 4C</option>
                <option value='MALIBU MAXX V6'>MALIBU MAXX V6</option>
                <option value='COLORADO PICKUP 2WD'>COLORADO PICKUP 2WD</option>
                <option value='REGAL'>REGAL</option>
                <option value='SANTA FE 2WD V6'>SANTA FE 2WD V6</option>
                <option value='GRAND CHEROKEE 2WD V'>GRAND CHEROKEE 2WD V</option>
                <option value='MALIBU 4C'>MALIBU 4C</option>
                <option value='AVEO'>AVEO</option>
                <option value='CHARGER V6'>CHARGER V6</option>
                <option value='AVENGER 4C'>AVENGER 4C</option>
                <option value='RIO'>RIO</option>
                <option value='PATRIOT 4WD 4C'>PATRIOT 4WD 4C</option>
                <option value='SORENTO 4WD'>SORENTO 4WD</option>
                <option value='JOURNEY FWD 4C'>JOURNEY FWD 4C</option>
                <option value='AURA'>AURA</option>
                <option value='AVENGER V6'>AVENGER V6</option>
                <option value='TRIBUTE 2WD V6'>TRIBUTE 2WD V6</option>
                <option value='F150 PICKUP 4WD V8'>F150 PICKUP 4WD V8</option>
                <option value='FUSION V6'>FUSION V6</option>
                <option value='TERRAZA FWD V6'>TERRAZA FWD V6</option>
                <option value='ENDEAVOR AWD'>ENDEAVOR AWD</option>
                <option value='VIBE'>VIBE</option>
                <option value='TOWN & COUNTRY 2WD V'>TOWN & COUNTRY 2WD V</option>
                <option value='CHARGER'>CHARGER</option>
                <option value='VERSA'>VERSA</option>
                <option value='JETTA 5C'>JETTA 5C</option>
                <option value='PACIFICA FWD 3.5L V6'>PACIFICA FWD 3.5L V6</option>
                <option value='IMPALA 3.5L V6 SFI'>IMPALA 3.5L V6 SFI</option>
                <option value='COBALT 2.2L I4 MPI'>COBALT 2.2L I4 MPI</option>
                <option value='SORENTO 4WD 3.5L V6'>SORENTO 4WD 3.5L V6</option>
                <option value='UPLANDER FWD V6 3.9L'>UPLANDER FWD V6 3.9L</option>
                <option value='VENTURE AWD V6'>VENTURE AWD V6</option>
                <option value='EXPEDITION 4WD V8 5.'>EXPEDITION 4WD V8 5.</option>
                <option value='TRACKER 4WD V6 2.5L'>TRACKER 4WD V6 2.5L</option>
                <option value='MALIBU V6 3.5L V6 SF'>MALIBU V6 3.5L V6 SF</option>
                <option value='MUSTANG V6 4.0L V6 E'>MUSTANG V6 4.0L V6 E</option>
                <option value='LIBERTY 4WD V6 3.7L'>LIBERTY 4WD V6 3.7L</option>
                <option value='BRAVADA AWD V6 4.2L'>BRAVADA AWD V6 4.2L</option>
                <option value='IMPALA 3.4L V6 SFI'>IMPALA 3.4L V6 SFI</option>
                <option value='CHARGER V6 2.7L V6 M'>CHARGER V6 2.7L V6 M</option>
                <option value='TAURUS 3.0L V6 EFI S'>TAURUS 3.0L V6 EFI S</option>
                <option value='300 2.7L V6 MPI'>300 2.7L V6 MPI</option>
                <option value='MONTE CARLO 3.5L V6'>MONTE CARLO 3.5L V6</option>
                <option value='MAGNUM V6 2.7L V6 MP'>MAGNUM V6 2.7L V6 MP</option>
                <option value='ION 2.2L I4 EFI / SF'>ION 2.2L I4 EFI / SF</option>
                <option value='AVEO 1.6L I4 EFI'>AVEO 1.6L I4 EFI</option>
                <option value='SEBRING 4C 2.4L I4 E'>SEBRING 4C 2.4L I4 E</option>
                <option value='MALIBU 4C 2.2L I4 MP'>MALIBU 4C 2.2L I4 MP</option>
                <option value='FIVE HUNDRED 3.0L V6'>FIVE HUNDRED 3.0L V6</option>
                <option value='MALIBU MAXX V6 3.5L'>MALIBU MAXX V6 3.5L</option>
                <option value='SEBRING 4C 2.4L I4 S'>SEBRING 4C 2.4L I4 S</option>
                <option value='SONATA V6 2.7L V6 MP'>SONATA V6 2.7L V6 MP</option>
                <option value='ELANTRA 2.0L I4 MPI'>ELANTRA 2.0L I4 MPI</option>
                <option value='MARINER 2WD V6 3.0L'>MARINER 2WD V6 3.0L</option>
                <option value='SEBRING V6 2.7L V6 M'>SEBRING V6 2.7L V6 M</option>
                <option value='TRAILBLAZER 4WD 6C 4'>TRAILBLAZER 4WD 6C 4</option>
                <option value='PT CRUISER 2.4L I4 M'>PT CRUISER 2.4L I4 M</option>
                <option value='ELANTRA MFI I-4 2.0L'>ELANTRA MFI I-4 2.0L</option>
                <option value='CAVALIER 4C 2.2L I4'>CAVALIER 4C 2.2L I4</option>
                <option value='ASCENDER 2WD 6C 4.2L'>ASCENDER 2WD 6C 4.2L</option>
                <option value='ALTIMA 2.5L I4 MPI'>ALTIMA 2.5L I4 MPI</option>
                <option value='HHR 2.2L I4 MPI'>HHR 2.2L I4 MPI</option>
                <option value='STRATUS 4C 2.4L I4 S'>STRATUS 4C 2.4L I4 S</option>
                <option value='GRAND PRIX 3.8L V6 S'>GRAND PRIX 3.8L V6 S</option>
                <option value='PT CRUISER 2.4L I4 S'>PT CRUISER 2.4L I4 S</option>
                <option value='STRATUS 4C 2.4L I4 M'>STRATUS 4C 2.4L I4 M</option>
                <option value='PT CRUISER 2.4L I-4'>PT CRUISER 2.4L I-4</option>
                <option value='SANTA FE 4WD V6 2.7L'>SANTA FE 4WD V6 2.7L</option>
                <option value='ECLIPSE'>ECLIPSE</option>
                <option value='GRAND AM V6 3.4L V6'>GRAND AM V6 3.4L V6</option>
                <option value='SONATA V6 3.3L V6 MP'>SONATA V6 3.3L V6 MP</option>
                <option value='BONNEVILLE 3.8L V6 S'>BONNEVILLE 3.8L V6 S</option>
                <option value='EQUINOX AWD V6 3.4L'>EQUINOX AWD V6 3.4L</option>
                <option value='FORENZA 2.0L I4 EFI'>FORENZA 2.0L I4 EFI</option>
                <option value='CONCORDE 3.5L V6 MPI'>CONCORDE 3.5L V6 MPI</option>
                <option value='ION 2.2L I4 EFI'>ION 2.2L I4 EFI</option>
                <option value='VENTURE FWD V6 3.4L'>VENTURE FWD V6 3.4L</option>
                <option value='ION 2.0L I4 MPI'>ION 2.0L I4 MPI</option>
                <option value='SENTRA 2.5L I-4 EFI'>SENTRA 2.5L I-4 EFI</option>
                <option value='SABLE 3.0L V6 EFI'>SABLE 3.0L V6 EFI</option>
                <option value='TAHOE 4WD 4.8L V8 SF'>TAHOE 4WD 4.8L V8 SF</option>
                <option value='SPORTAGE 2WD 4C 2.0L'>SPORTAGE 2WD 4C 2.0L</option>
                <option value='DURANGO 4WD V8 5.7L'>DURANGO 4WD V8 5.7L</option>
                <option value='MALIBU V6 3.1L V6 SF'>MALIBU V6 3.1L V6 SF</option>
                <option value='WINDSTAR FWD V6 3.8L'>WINDSTAR FWD V6 3.8L</option>
                <option value='ALTIMA 3.5L V6 MPI'>ALTIMA 3.5L V6 MPI</option>
                <option value='PACIFICA AWD 3.5L V6'>PACIFICA AWD 3.5L V6</option>
                <option value='SONATA 4C 2.4L I4 MP'>SONATA 4C 2.4L I4 MP</option>
                <option value='VIBE 1.8L I4 MPI'>VIBE 1.8L I4 MPI</option>
                <option value='MAZDA6 2.3L I4 MFI /'>MAZDA6 2.3L I4 MFI /</option>
                <option value='EXPLORER 4WD V6 4.0L'>EXPLORER 4WD V6 4.0L</option>
                <option value='FOCUS 2.0L I-4 EFI D'>FOCUS 2.0L I-4 EFI D</option>
                <option value='ACCORD V6 3.0L V6 EF'>ACCORD V6 3.0L V6 EF</option>
                <option value='ESCAPE 2WD V6 3.0L V'>ESCAPE 2WD V6 3.0L V</option>
                <option value='VUE AWD 4C 2.2L I4 M'>VUE AWD 4C 2.2L I4 M</option>
                <option value='RENDEZVOUS FWD 3.4L'>RENDEZVOUS FWD 3.4L</option>
                <option value='ACCENT 1.6L I4 MPI'>ACCENT 1.6L I4 MPI</option>
                <option value='TOWN CAR 4.6L V8 EFI'>TOWN CAR 4.6L V8 EFI</option>
                <option value='OPTIMA 4C 2.4L I4 MP'>OPTIMA 4C 2.4L I4 MP</option>
                <option value='FOCUS 2.0L I4 SFI'>FOCUS 2.0L I4 SFI</option>
                <option value='MONTE CARLO 3.4L V6'>MONTE CARLO 3.4L V6</option>
                <option value='FREESTYLE 2WD V6 3.0'>FREESTYLE 2WD V6 3.0</option>
                <option value='MILAN V6'>MILAN V6</option>
                <option value='LIBERTY 4WD V6'>LIBERTY 4WD V6</option>
                <option value='CARAVAN FWD 4C'>CARAVAN FWD 4C</option>
                <option value='XL-7 4WD'>XL-7 4WD</option>
                <option value='FREESTYLE AWD V6'>FREESTYLE AWD V6</option>
                <option value='GRAND AM V6'>GRAND AM V6</option>
                <option value='S SERIES'>S SERIES</option>
                <option value='PACIFICA AWD'>PACIFICA AWD</option>
                <option value='EQUINOX AWD V6'>EQUINOX AWD V6</option>
                <option value='HIGHLANDER 2WD V6'>HIGHLANDER 2WD V6</option>
                <option value='TRAILBLAZER EXT 4WD'>TRAILBLAZER EXT 4WD</option>
                <option value='LANCER'>LANCER</option>
                <option value='MAXIMA'>MAXIMA</option>
                <option value='EXPEDITION 4WD V8'>EXPEDITION 4WD V8</option>
                <option value='COOPER'>COOPER</option>
                <option value='ACCORD V6'>ACCORD V6</option>
                <option value='GRAND AM 4C'>GRAND AM 4C</option>
                <option value='MILAN 4C'>MILAN 4C</option>
                <option value='ENVOY 4WD 6C'>ENVOY 4WD 6C</option>
                <option value='RENDEZVOUS AWD'>RENDEZVOUS AWD</option>
                <option value='CENTURY V6'>CENTURY V6</option>
                <option value='TRAILBLAZER 4WD 6C'>TRAILBLAZER 4WD 6C</option>
                <option value='TRIBUTE 4WD V6'>TRIBUTE 4WD V6</option>
                <option value='MONTEGO'>MONTEGO</option>
                <option value='S10 PICKUP 2WD 4C'>S10 PICKUP 2WD 4C</option>
                <option value='GRAND CHEROKEE 4WD V'>GRAND CHEROKEE 4WD V</option>
                <option value='1500 RAM PICKUP 4WD'>1500 RAM PICKUP 4WD</option>
                <option value='TORRENT FWD V6'>TORRENT FWD V6</option>
                <option value='AVALANCHE 1500 4WD V'>AVALANCHE 1500 4WD V</option>
                <option value='EXPLORER 2WD V8'>EXPLORER 2WD V8</option>
                <option value='TAHOE 4WD'>TAHOE 4WD</option>
                <option value='GALANT V6'>GALANT V6</option>
                <option value='NEON 2.0L I-4 SFI SO'>NEON 2.0L I-4 SFI SO</option>
                <option value='TAURUS 3.0L V6 EFI'>TAURUS 3.0L V6 EFI</option>
                <option value='SPECTRA 2.0L I4 EFI'>SPECTRA 2.0L I4 EFI</option>
                <option value='PACIFICA FWD 3.8L V6'>PACIFICA FWD 3.8L V6</option>
                <option value='CHARGER V6 3.5L V6 E'>CHARGER V6 3.5L V6 E</option>
                <option value='CAMRY SOLARA V6 3.0L'>CAMRY SOLARA V6 3.0L</option>
                <option value='RIO 1.6L I4 MPI'>RIO 1.6L I4 MPI</option>
                <option value='CIVIC'>CIVIC</option>
                <option value='TRAILBLAZER 2WD 6C 4'>TRAILBLAZER 2WD 6C 4</option>
                <option value='MAGNUM V6 3.5L V6 MP'>MAGNUM V6 3.5L V6 MP</option>
                <option value='CHARGER 3.5L V6 EFI'>CHARGER 3.5L V6 EFI</option>
                <option value='LACROSSE 3.8L V6 SFI'>LACROSSE 3.8L V6 SFI</option>
                <option value='G6 4C 2.4L I4 MPI'>G6 4C 2.4L I4 MPI</option>
                <option value='IMPALA V6 3.5L V6 SF'>IMPALA V6 3.5L V6 SF</option>
                <option value='MUSTANG V6 3.8L V6 E'>MUSTANG V6 3.8L V6 E</option>
                <option value='G6 V6 3.5L V6 SFI'>G6 V6 3.5L V6 SFI</option>
                <option value='RENO 2.0L I4 EFI'>RENO 2.0L I4 EFI</option>
                <option value='CARAVAN FWD 4C 2.4L'>CARAVAN FWD 4C 2.4L</option>
                <option value='ACCORD 4C 2.4L I4 MP'>ACCORD 4C 2.4L I4 MP</option>
                <option value='EXPLORER 2WD V6 4.0L'>EXPLORER 2WD V6 4.0L</option>
                <option value='ALTIMA 2.5L I-4 EFI'>ALTIMA 2.5L I-4 EFI</option>
                <option value='MAXIMA MFI V6 3.5L D'>MAXIMA MFI V6 3.5L D</option>
                <option value='300 3.5L V6 MPI'>300 3.5L V6 MPI</option>
                <option value='ECLIPSE 2.4L I4 MPI'>ECLIPSE 2.4L I4 MPI</option>
                <option value='TAURUS 3.0L V6 EFI /'>TAURUS 3.0L V6 EFI /</option>
                <option value='LIBERTY 2WD V6 3.7L'>LIBERTY 2WD V6 3.7L</option>
                <option value='CHARGER 2.7L V6 MPI'>CHARGER 2.7L V6 MPI</option>
                <option value='MILAN V6 3.0L V6 EFI'>MILAN V6 3.0L V6 EFI</option>
                <option value='FIREBIRD V6 3.8L V6'>FIREBIRD V6 3.8L V6</option>
                <option value='PATRIOT 2WD 4C'>PATRIOT 2WD 4C</option>
                <option value='RONDO V6'>RONDO V6</option>
                <option value='FORESTER AWD'>FORESTER AWD</option>
                <option value='XTERRA 2WD 4C'>XTERRA 2WD 4C</option>
                <option value='DAKOTA PICKUP 2WD V8'>DAKOTA PICKUP 2WD V8</option>
                <option value='TIBURON'>TIBURON</option>
                <option value='CAMRY SOLARA V6'>CAMRY SOLARA V6</option>
                <option value='MONTANA'>MONTANA</option>
                <option value='NITRO 2WD V6'>NITRO 2WD V6</option>
                <option value='YARIS'>YARIS</option>
                <option value='G5 4C'>G5 4C</option>
                <option value='AURA V6'>AURA V6</option>
                <option value='RANGER PICKUP 2WD 4C'>RANGER PICKUP 2WD 4C</option>
                <option value='SPORTAGE 2WD 4C'>SPORTAGE 2WD 4C</option>
                <option value='MOUNTAINEER 2WD V6'>MOUNTAINEER 2WD V6</option>
                <option value='CROWN VICTORIA'>CROWN VICTORIA</option>
                <option value='ALERO V6'>ALERO V6</option>
                <option value='300M'>300M</option>
                <option value='GRAND CHEROKEE 4WD 6'>GRAND CHEROKEE 4WD 6</option>
                <option value='LE SABRE'>LE SABRE</option>
                <option value='MATRIX 2WD'>MATRIX 2WD</option>
                <option value='VOYAGER FWD 4C'>VOYAGER FWD 4C</option>
                <option value='SENTRA 1.8L I4 EFI'>SENTRA 1.8L I4 EFI</option>
                <option value='ENVOY 2WD 6C 4.2L I-'>ENVOY 2WD 6C 4.2L I-</option>
                <option value='F150 PICKUP 2WD V8 5'>F150 PICKUP 2WD V8 5</option>
                <option value='ION 2.2L I4 MPI'>ION 2.2L I4 MPI</option>
                <option value='ALERO V6 3.4L V6 MPI'>ALERO V6 3.4L V6 MPI</option>
                <option value='COBALT 2.2L I4 MPI /'>COBALT 2.2L I4 MPI /</option>
                <option value='UPLANDER FWD V6 3.5L'>UPLANDER FWD V6 3.5L</option>
                <option value='VUE 2WD 4C 2.2L I4 M'>VUE 2WD 4C 2.2L I4 M</option>
                <option value='GRAND VITARA 2WD 2.5'>GRAND VITARA 2WD 2.5</option>
                <option value='AVEO 1.6L I-4 EFI DO'>AVEO 1.6L I-4 EFI DO</option>
                <option value='MOUNTAINEER AWD V6 4'>MOUNTAINEER AWD V6 4</option>
                <option value='XL-7 2WD 3.6L V6 EFI'>XL-7 2WD 3.6L V6 EFI</option>
                <option value='DURANGO 2WD V8 4.7L'>DURANGO 2WD V8 4.7L</option>
                <option value='AVEO 1.6L I4 EFI / M'>AVEO 1.6L I4 EFI / M</option>
                <option value='ACCORD 4C 2.4L I-4 M'>ACCORD 4C 2.4L I-4 M</option>
                <option value='CALIBER 2.0L I4 SFI'>CALIBER 2.0L I4 SFI</option>
                <option value='TAHOE 2WD 4.8L V8 SF'>TAHOE 2WD 4.8L V8 SF</option>
                <option value='F150 PICKUP 2WD V8 4'>F150 PICKUP 2WD V8 4</option>
                <option value='SORENTO 2WD 3.5L V6'>SORENTO 2WD 3.5L V6</option>
                <option value='EQUINOX FWD V6 3.4L'>EQUINOX FWD V6 3.4L</option>
                <option value='MALIBU 4C 2.2L I4 MF'>MALIBU 4C 2.2L I4 MF</option>
                <option value='ENVOY 2WD 6C 4.2L I6'>ENVOY 2WD 6C 4.2L I6</option>
                <option value='TITAN PICKUP 2WD V8'>TITAN PICKUP 2WD V8</option>
                <option value='GRAND AM 4C 2.2L I4'>GRAND AM 4C 2.2L I4</option>
                <option value='ALTIMA 2.5L I4 MPI /'>ALTIMA 2.5L I4 MPI /</option>
                <option value='AVENGER 4C 2.4L I4 S'>AVENGER 4C 2.4L I4 S</option>
                <option value='IMPALA 3.9L V6 SFI'>IMPALA 3.9L V6 SFI</option>
                <option value='HHR 2.4L I-4 MPI'>HHR 2.4L I-4 MPI</option>
                <option value='MONTANA FWD 3.5L V6'>MONTANA FWD 3.5L V6</option>
                <option value='MAXIMA 3.5L V6 MPI'>MAXIMA 3.5L V6 MPI</option>
                <option value='CENTURY V6 3.1L V6 S'>CENTURY V6 3.1L V6 S</option>
                <option value='FUSION 4C 2.3L I4 EF'>FUSION 4C 2.3L I4 EF</option>
                <option value='RONDO V6 2.7L V6 DI'>RONDO V6 2.7L V6 DI</option>
                <option value='FREESTYLE FWD V6 3.0'>FREESTYLE FWD V6 3.0</option>
                <option value='DURANGO 4WD V8 4.7L'>DURANGO 4WD V8 4.7L</option>
                <option value='IMPALA V6 3.5L V6 MP'>IMPALA V6 3.5L V6 MP</option>
                <option value='IMPALA 3.8L V6 SFI'>IMPALA 3.8L V6 SFI</option>
                <option value='LACROSSE'>LACROSSE</option>
                <option value='TUNDRA PICKUP 2WD V8'>TUNDRA PICKUP 2WD V8</option>
                <option value='MARINER 2WD V6'>MARINER 2WD V6</option>
                <option value='GRAND MARQUIS'>GRAND MARQUIS</option>
                <option value='AURA 4C'>AURA 4C</option>
                <option value='MARINER 4WD V6'>MARINER 4WD V6</option>
                <option value='EXPLORER AWD V6'>EXPLORER AWD V6</option>
                <option value='BEETLE'>BEETLE</option>
                <option value='VUE 2WD V6'>VUE 2WD V6</option>
                <option value='YUKON XL 1500 4WD'>YUKON XL 1500 4WD</option>
                <option value='SONATA 4C MFI I-4 2.'>SONATA 4C MFI I-4 2.</option>
                <option value='SANTA FE 2WD V6 2.7L'>SANTA FE 2WD V6 2.7L</option>
                <option value='NEON 2.0L I4 SFI'>NEON 2.0L I4 SFI</option>
                <option value='XG 350 3.5L V6 EFI /'>XG 350 3.5L V6 EFI /</option>
                <option value='TRACKER 2WD 4C 2.0L'>TRACKER 2WD 4C 2.0L</option>
                <option value='GRAND CHEROKEE 2WD 6'>GRAND CHEROKEE 2WD 6</option>
                <option value='LANCER 2.0L I4 MPI'>LANCER 2.0L I4 MPI</option>
                <option value='MUSTANG V6 3.9L V6 E'>MUSTANG V6 3.9L V6 E</option>
                <option value='SABLE 3.0L V6 EFI DO'>SABLE 3.0L V6 EFI DO</option>
                <option value='SPORTAGE 2WD Multipl'>SPORTAGE 2WD Multipl</option>
                <option value='FREESTAR FWD V6 3.9L'>FREESTAR FWD V6 3.9L</option>
                <option value='FREESTYLE AWD V6 3.0'>FREESTYLE AWD V6 3.0</option>
                <option value='ESCAPE 4WD V6 3.0L V'>ESCAPE 4WD V6 3.0L V</option>
                <option value='XTERRA 2WD V6 3.3L V'>XTERRA 2WD V6 3.3L V</option>
                <option value='ELEMENT 2WD 2.4L I4'>ELEMENT 2WD 2.4L I4</option>
                <option value='LE SABRE 3.8L V6 MFI'>LE SABRE 3.8L V6 MFI</option>
                <option value='EXPEDITION 2WD V8 5.'>EXPEDITION 2WD V8 5.</option>
                <option value='SPECTRA 1.8L I4 EFI'>SPECTRA 1.8L I4 EFI</option>
                <option value='OPTIMA V6'>OPTIMA V6</option>
                <option value='VUE AWD V6'>VUE AWD V6</option>
                <option value='BRAVADA AWD V6'>BRAVADA AWD V6</option>
                <option value='CONCORDE'>CONCORDE</option>
                <option value='CAMRY SOLARA 4C'>CAMRY SOLARA 4C</option>
                <option value='FRONTIER PICKUP 2WD'>FRONTIER PICKUP 2WD</option>
                <option value='TOWN CAR'>TOWN CAR</option>
                <option value='MPV 2WD V6'>MPV 2WD V6</option>
                <option value='SANTA FE 2WD 4C'>SANTA FE 2WD 4C</option>
                <option value='2500 RAM PICKUP 4WD'>2500 RAM PICKUP 4WD</option>
                <option value='PROTEGE'>PROTEGE</option>
                <option value='626 V6 2.5L V6 EFI D'>626 V6 2.5L V6 EFI D</option>
                <option value='S SERIES 1.9L I-4 SF'>S SERIES 1.9L I-4 SF</option>
                <option value='FOCUS 2.0L I4 SPI'>FOCUS 2.0L I4 SPI</option>
                <option value='BONNEVILLE 3.8L V6 M'>BONNEVILLE 3.8L V6 M</option>
                <option value='RENO 2.0L I4 DI / EF'>RENO 2.0L I4 DI / EF</option>
                <option value='INTREPID 3.5L V6 MPI'>INTREPID 3.5L V6 MPI</option>
                <option value='BEETLE 2.0L I4 EFI'>BEETLE 2.0L I4 EFI</option>
                <option value='FOCUS 2.0L I-4 SFI S'>FOCUS 2.0L I-4 SFI S</option>
                <option value='STRATUS V6 2.7L V6 M'>STRATUS V6 2.7L V6 M</option>
                <option value='CARAVAN FWD V6 3.3L'>CARAVAN FWD V6 3.3L</option>
                <option value='SABLE 3.0L V6 2V /EF'>SABLE 3.0L V6 2V /EF</option>
                <option value='ESCAPE 2WD 4C 2.0L I'>ESCAPE 2WD 4C 2.0L I</option>
                <option value='LANCER 2.4L I4 MPI'>LANCER 2.4L I4 MPI</option>
                <option value='L SERIES 2.2L I4 MPI'>L SERIES 2.2L I4 MPI</option>
                <option value='TACOMA PICKUP 2WD 4C'>TACOMA PICKUP 2WD 4C</option>
                <option value='TAURUS 3.0L V6 EFI F'>TAURUS 3.0L V6 EFI F</option>
                <option value='ESCAPE 2WD 4C 2.3L I'>ESCAPE 2WD 4C 2.3L I</option>
                <option value='OUTLANDER 2WD 4C 2.4'>OUTLANDER 2WD 4C 2.4</option>
                <option value='ALERO 4C 2.4L I4 SFI'>ALERO 4C 2.4L I4 SFI</option>
                <option value='PARK AVENUE 3.8L V6'>PARK AVENUE 3.8L V6</option>
                <option value='GRAND PRIX 3.1L V6 S'>GRAND PRIX 3.1L V6 S</option>
                <option value='MATRIX AWD'>MATRIX AWD</option>
                <option value='L SERIES 2.0L I-4 MP'>L SERIES 2.0L I-4 MP</option>
                <option value='ENDEAVOR FWD 3.8L V6'>ENDEAVOR FWD 3.8L V6</option>
                <option value='FOCUS 2.3L I-4 DOHC'>FOCUS 2.3L I-4 DOHC</option>
                <option value='MAZDA3 2.0L I-4 MPI'>MAZDA3 2.0L I-4 MPI</option>
                <option value='ECHO 1.5L I4 EFI'>ECHO 1.5L I4 EFI</option>
                <option value='PROTEGE 5 2.0L I-4 M'>PROTEGE 5 2.0L I-4 M</option>
                <option value='RENDEZVOUS AWD 3.4L'>RENDEZVOUS AWD 3.4L</option>
                <option value='F150 PICKUP 2WD V6 4'>F150 PICKUP 2WD V6 4</option>
                <option value='XG 350'>XG 350</option>
                <option value='SANTA FE 4WD V6'>SANTA FE 4WD V6</option>
                <option value='TRACKER 2WD 4C'>TRACKER 2WD 4C</option>
                <option value='SONOMA PICKUP 2WD V6'>SONOMA PICKUP 2WD V6</option>
                <option value='HIGHLANDER 2WD 4C'>HIGHLANDER 2WD 4C</option>
                <option value='RAINIER RWD V6'>RAINIER RWD V6</option>
                <option value='SORENTO 2WD'>SORENTO 2WD</option>
                <option value='MAGNUM V8'>MAGNUM V8</option>
                <option value='300 3.5L V6 MPI / SM'>300 3.5L V6 MPI / SM</option>
                <option value='BEETLE 2.0L I4 MFI /'>BEETLE 2.0L I4 MFI /</option>
                <option value='DURANGO 2WD V6 3.7L'>DURANGO 2WD V6 3.7L</option>
                <option value='HHR 2.2L I4 MPI / SF'>HHR 2.2L I4 MPI / SF</option>
                <option value='LACROSSE 3.6L V6 SFI'>LACROSSE 3.6L V6 SFI</option>
                <option value='XB 1.5L I-4 EFI DOHC'>XB 1.5L I-4 EFI DOHC</option>
                <option value='300 3.5L / 6.0L V12'>300 3.5L / 6.0L V12</option>
                <option value='PACIFICA AWD 4.0L V6'>PACIFICA AWD 4.0L V6</option>
                <option value='MAZDA6 2.3L I4 MPI'>MAZDA6 2.3L I4 MPI</option>
                <option value='NITRO 4WD V6 3.7L V6'>NITRO 4WD V6 3.7L V6</option>
                <option value='PACIFICA FWD 4.0L V6'>PACIFICA FWD 4.0L V6</option>
                <option value='MUSTANG V6 Unspecifi'>MUSTANG V6 Unspecifi</option>
                <option value='MONTANA FWD'>MONTANA FWD</option>
                <option value='1500 SIERRA PICKUP 4'>1500 SIERRA PICKUP 4</option>
                <option value='PATRIOT FWD 4C'>PATRIOT FWD 4C</option>
                <option value='AVENGER'>AVENGER</option>
                <option value='COMMANDER 2WD V8'>COMMANDER 2WD V8</option>
                <option value='MALIBU V6 3.5L V6 MF'>MALIBU V6 3.5L V6 MF</option>
                <option value='FORENZA 2.0L I4 DI /'>FORENZA 2.0L I4 DI /</option>
                <option value='TERRAZA FWD V6 3.5L'>TERRAZA FWD V6 3.5L</option>
                <option value='MAZDA6 3.0L V6 MFI /'>MAZDA6 3.0L V6 MFI /</option>
                <option value='ENVOY XL 2WD V8'>ENVOY XL 2WD V8</option>
                <option value='SEDONA'>SEDONA</option>
                <option value='ARMADA 4WD V8'>ARMADA 4WD V8</option>
                <option value='ENVOY 4WD 6C 4.2L I6'>ENVOY 4WD 6C 4.2L I6</option>
                <option value='SEBRING V6 3.0L V6 M'>SEBRING V6 3.0L V6 M</option>
                <option value='RIO MFI I-4 1.6L DOH'>RIO MFI I-4 1.6L DOH</option>
                <option value='HHR 2.2L I-4 MPI DOH'>HHR 2.2L I-4 MPI DOH</option>
                <option value='GRAND PRIX 3.8L V6 M'>GRAND PRIX 3.8L V6 M</option>
                <option value='AMANTI 3.5L V6 MPI'>AMANTI 3.5L V6 MPI</option>
                <option value='ALTIMA 2.4L I4 EFI'>ALTIMA 2.4L I4 EFI</option>
                <option value='REGAL 3.8L V6 MFI SC'>REGAL 3.8L V6 MFI SC</option>
                <option value='TAHOE 2WD 5.3L V8 SF'>TAHOE 2WD 5.3L V8 SF</option>
                <option value='YUKON XL 1500 2WD 5.'>YUKON XL 1500 2WD 5.</option>
                <option value='LE SABRE Unspecified'>LE SABRE Unspecified</option>
                <option value='LANCER 2.4L I4 EFI'>LANCER 2.4L I4 EFI</option>
                <option value='MONTANA 3.4L V6 SFI'>MONTANA 3.4L V6 SFI</option>
                <option value='TAHOE 4WD 5.3L V8 SF'>TAHOE 4WD 5.3L V8 SF</option>
                <option value='MONTERO SPORT 2WD V6'>MONTERO SPORT 2WD V6</option>
                <option value='MONTANA 3.4L V6 EFI'>MONTANA 3.4L V6 EFI</option>
                <option value='CAMRY V6 3.0L V6 SFI'>CAMRY V6 3.0L V6 SFI</option>
                <option value='S SERIES 1.9L I4 SFI'>S SERIES 1.9L I4 SFI</option>
                <option value='VIBE 1.8L I4 MFI / M'>VIBE 1.8L I4 MFI / M</option>
                <option value='COMMANDER 2WD V6 3.7'>COMMANDER 2WD V6 3.7</option>
                <option value='4 RUNNER 2WD V8 4.7L'>4 RUNNER 2WD V8 4.7L</option>
                <option value='SUBURBAN 1500 4WD'>SUBURBAN 1500 4WD</option>
                <option value='COMMANDER 2WD V6'>COMMANDER 2WD V6</option>
                <option value='MONTEGO 3.0L V6 EFI'>MONTEGO 3.0L V6 EFI</option>
                <option value='G5 4C 2.2L I4 MPI'>G5 4C 2.2L I4 MPI</option>
                <option value='GALANT 4C 2.4L I4 EF'>GALANT 4C 2.4L I4 EF</option>
                <option value='ENVOY XL 4WD V8'>ENVOY XL 4WD V8</option>
                <option value='MOUNTAINEER AWD V8'>MOUNTAINEER AWD V8</option>
                <option value='MOUNTAINEER AWD V6'>MOUNTAINEER AWD V6</option>
                <option value='ASCENDER 2WD 6C'>ASCENDER 2WD 6C</option>
                <option value='COMMANDER 4WD V8'>COMMANDER 4WD V8</option>
                <option value='ELEMENT 4WD'>ELEMENT 4WD</option>
                <option value='CTS'>CTS</option>
                <option value='MONTEREY'>MONTEREY</option>
                <option value='QUEST 3.5L V6 EFI /'>QUEST 3.5L V6 EFI /</option>
                <option value='MARINER 4WD V6 3.0L'>MARINER 4WD V6 3.0L</option>
                <option value='G6 4C 2.4L I4 MFI /'>G6 4C 2.4L I4 MFI /</option>
                <option value='XL-7 4WD 2.7L V6 MPI'>XL-7 4WD 2.7L V6 MPI</option>
                <option value='COMMANDER 4WD V8 4.7'>COMMANDER 4WD V8 4.7</option>
                <option value='ALERO 4C 2.2L I4 MPI'>ALERO 4C 2.2L I4 MPI</option>
                <option value='TRIBUTE 4WD V6 3.0L'>TRIBUTE 4WD V6 3.0L</option>
                <option value='DURANGO 2WD V8 5.7L'>DURANGO 2WD V8 5.7L</option>
                <option value='COMMANDER 4WD V6'>COMMANDER 4WD V6</option>
                <option value='HIGHLANDER 2WD V6 3.'>HIGHLANDER 2WD V6 3.</option>
                <option value='TAURUS X FWD V6'>TAURUS X FWD V6</option>
                <option value='2500HD SILVERADO PIC'>2500HD SILVERADO PIC</option>
                <option value='S40'>S40</option>
                <option value='2500 RAM PICKUP 2WD'>2500 RAM PICKUP 2WD</option>
                <option value='YUKON XL 1500 2WD'>YUKON XL 1500 2WD</option>
                <option value='MPV 2WD V6 3.0L V6 M'>MPV 2WD V6 3.0L V6 M</option>
                <option value='VIBE 1.8L I-4 MPI'>VIBE 1.8L I-4 MPI</option>
                <option value='SUNFIRE 2.2L I4 MPI'>SUNFIRE 2.2L I4 MPI</option>
                <option value='MOUNTAINEER 2WD V8'>MOUNTAINEER 2WD V8</option>
                <option value='AVALON'>AVALON</option>
                <option value='COMPASS 4WD 4C'>COMPASS 4WD 4C</option>
                <option value='DAKOTA PICKUP 4WD V6'>DAKOTA PICKUP 4WD V6</option>
                <option value='ASPEN 2WD V8'>ASPEN 2WD V8</option>
                <option value='MURANO 2WD V6'>MURANO 2WD V6</option>
                <option value='QUEST'>QUEST</option>
                <option value='QX4 4WD V6'>QX4 4WD V6</option>
                <option value='MIATA MX-5'>MIATA MX-5</option>
                <option value='JETTA 4C'>JETTA 4C</option>
                <option value='RIO 5'>RIO 5</option>
                <option value='ION 2.2L I4 MPI / SF'>ION 2.2L I4 MPI / SF</option>
                <option value='EXPLORER 4WD V8'>EXPLORER 4WD V8</option>
                <option value='CONTINENTAL'>CONTINENTAL</option>
                <option value='SRX AWD V6'>SRX AWD V6</option>
                <option value='NITRO 4WD V6'>NITRO 4WD V6</option>
                <option value='GRAND VITARA 2WD'>GRAND VITARA 2WD</option>
                <option value='XA'>XA</option>
                <option value='TAURUS 3.0L V6 SFI'>TAURUS 3.0L V6 SFI</option>
                <option value='ENVOY XL 2WD 6C 4.2L'>ENVOY XL 2WD 6C 4.2L</option>
                <option value='FREESTAR FWD V6 4.2L'>FREESTAR FWD V6 4.2L</option>
                <option value='NEON 2.0L I4 SFI / S'>NEON 2.0L I4 SFI / S</option>
                <option value='OPTIMA V6 MFI V6 2.7'>OPTIMA V6 MFI V6 2.7</option>
                <option value='ACCENT MFI I-4 1.6L'>ACCENT MFI I-4 1.6L</option>
                <option value='G6 4C 2.4L I-4 MPI'>G6 4C 2.4L I-4 MPI</option>
                <option value='EXPEDITION 2WD V8 4.'>EXPEDITION 2WD V8 4.</option>
                <option value='FOCUS 2.0L I-4 SFI D'>FOCUS 2.0L I-4 SFI D</option>
                <option value='SEBRING 4C 2.4L I-4'>SEBRING 4C 2.4L I-4</option>
                <option value='ALTIMA 2.5L I4 EFI'>ALTIMA 2.5L I4 EFI</option>
                <option value='EXPEDITION 4WD V8 4.'>EXPEDITION 4WD V8 4.</option>
                <option value='RELAY 2WD V6 3.5L V6'>RELAY 2WD V6 3.5L V6</option>
                <option value='SUBURBAN 1500 2WD 5.'>SUBURBAN 1500 2WD 5.</option>
                <option value='VITARA 2WD 4C MFI V6'>VITARA 2WD 4C MFI V6</option>
                <option value='CANYON PICKUP 2WD I5'>CANYON PICKUP 2WD I5</option>
                <option value='ENVOY XL 2WD V8 5.3L'>ENVOY XL 2WD V8 5.3L</option>
                <option value='DURANGO 4WD V8 SEFI'>DURANGO 4WD V8 SEFI</option>
                <option value='SENTRA 1.8L I4 EFI /'>SENTRA 1.8L I4 EFI /</option>
                <option value='VERONA 2.5L I6 MPI'>VERONA 2.5L I6 MPI</option>
                <option value='ALTIMA MFI I-4 2.5L'>ALTIMA MFI I-4 2.5L</option>
                <option value='AXIOM 2WD V6 3.5L V6'>AXIOM 2WD V6 3.5L V6</option>
                <option value='MARINER 4WD 4C'>MARINER 4WD 4C</option>
                <option value='SEBRING V6 MFI V6 2.'>SEBRING V6 MFI V6 2.</option>
                <option value='COBALT 2.2L I-4 MPI'>COBALT 2.2L I-4 MPI</option>
                <option value='S10 PICKUP 2WD 4C 2.'>S10 PICKUP 2WD 4C 2.</option>
                <option value='YUKON 4WD V8 4.8L V8'>YUKON 4WD V8 4.8L V8</option>
                <option value='S10 PICKUP 4WD V6 4.'>S10 PICKUP 4WD V6 4.</option>
                <option value='SPECTRA 5 2.0L I4 EF'>SPECTRA 5 2.0L I4 EF</option>
                <option value='SANTA FE 2WD 4C 2.4L'>SANTA FE 2WD 4C 2.4L</option>
                <option value='COLORADO PICKUP 4WD'>COLORADO PICKUP 4WD</option>
                <option value='FOCUS 2.0L I4 EFI'>FOCUS 2.0L I4 EFI</option>
                <option value='AVEO 1.6L I-4 MPI DO'>AVEO 1.6L I-4 MPI DO</option>
                <option value='SUBURBAN 1500 4WD 5.'>SUBURBAN 1500 4WD 5.</option>
                <option value='ECLIPSE 3.8L V6 MPI'>ECLIPSE 3.8L V6 MPI</option>
                <option value='CAMRY 4C 2.4L I-4 SF'>CAMRY 4C 2.4L I-4 SF</option>
                <option value='SABLE 3.0L V6 4V /EF'>SABLE 3.0L V6 4V /EF</option>
                <option value='MILAN 4C 2.3L I4 EFI'>MILAN 4C 2.3L I4 EFI</option>
                <option value='SPORTAGE 2WD 4C 2.7L'>SPORTAGE 2WD 4C 2.7L</option>
                <option value='I-280 PICKUP 2WD 4C'>I-280 PICKUP 2WD 4C</option>
                <option value='RONDO 4C'>RONDO 4C</option>
                <option value='MONTE CARLO 3.9L V6'>MONTE CARLO 3.9L V6</option>
                <option value='CAMRY 4C 2.4L I4 SFI'>CAMRY 4C 2.4L I4 SFI</option>
                <option value='TRIBUTE 2WD 4C 2.3L'>TRIBUTE 2WD 4C 2.3L</option>
                <option value='IMPALA 3.5L V6 SFI F'>IMPALA 3.5L V6 SFI F</option>
                <option value='MONTERO SPORT 4WD V6'>MONTERO SPORT 4WD V6</option>
                <option value='YUKON 2WD V8 4.8L V8'>YUKON 2WD V8 4.8L V8</option>
                <option value='MAGNUM V8 5.7L V8 SF'>MAGNUM V8 5.7L V8 SF</option>
                <option value='AZERA 3.8L V6 MPI'>AZERA 3.8L V6 MPI</option>
                <option value='CANYON PICKUP 4WD I5'>CANYON PICKUP 4WD I5</option>
                <option value='PT CRUISER 2.4L I4 D'>PT CRUISER 2.4L I4 D</option>
                <option value='UPLANDER AWD V6'>UPLANDER AWD V6</option>
                <option value='XL-7 2WD'>XL-7 2WD</option>
                <option value='GS450H'>GS450H</option>
                <option value='MONTE CARLO 3.8L V6'>MONTE CARLO 3.8L V6</option>
                <option value='ELEMENT 4WD 2.4L I4'>ELEMENT 4WD 2.4L I4</option>
                <option value='G6 V6 3.5L V6 MFI /'>G6 V6 3.5L V6 MFI /</option>
                <option value='TORRENT FWD V6 3.4L'>TORRENT FWD V6 3.4L</option>
                <option value='L SERIES 2.2L I4 SFI'>L SERIES 2.2L I4 SFI</option>
                <option value='RENDEZVOUS FWD 3.5L'>RENDEZVOUS FWD 3.5L</option>
                <option value='ALERO 4C 2.2L I-4 MP'>ALERO 4C 2.2L I-4 MP</option>
                <option value='GALANT 4C Multiple E'>GALANT 4C Multiple E</option>
                <option value='COMPASS 2WD 4C 2.4L'>COMPASS 2WD 4C 2.4L</option>
                <option value='VIBE AWD MFI I-4 1.8'>VIBE AWD MFI I-4 1.8</option>
                <option value='G35'>G35</option>
                <option value='RAINIER AWD V6'>RAINIER AWD V6</option>
                <option value='GS300'>GS300</option>
                <option value='BONNEVILLE'>BONNEVILLE</option>
                <option value='ODYSSEY'>ODYSSEY</option>
                <option value='OUTLANDER AWD 4C'>OUTLANDER AWD 4C</option>
                <option value='NAVIGATOR 4WD V8'>NAVIGATOR 4WD V8</option>
                <option value='TORRENT AWD V6'>TORRENT AWD V6</option>
                <option value='S10 PICKUP 2WD V6'>S10 PICKUP 2WD V6</option>
                <option value='OPTIMA'>OPTIMA</option>
                <option value='YUKON 2WD V8'>YUKON 2WD V8</option>
                <option value='SABLE 3.0L V6 EFI SO'>SABLE 3.0L V6 EFI SO</option>
                <option value='MONTEREY 4.2L V6 SPI'>MONTEREY 4.2L V6 SPI</option>
                <option value='AVEO 1.6L I4 DOHC'>AVEO 1.6L I4 DOHC</option>
                <option value='GALANT V6 3.0L V6 EF'>GALANT V6 3.0L V6 EF</option>
                <option value='SENTRA 1.8L I-4 EFI'>SENTRA 1.8L I-4 EFI</option>
                <option value='NAVIGATOR 2WD V8 5.4'>NAVIGATOR 2WD V8 5.4</option>
                <option value='MARINER 2WD 4C 2.3L'>MARINER 2WD 4C 2.3L</option>
                <option value='300M 3.5L V6 MPI'>300M 3.5L V6 MPI</option>
                <option value='PROTEGE 2.0L I4 EFI'>PROTEGE 2.0L I4 EFI</option>
                <option value='XTERRA 4WD V6 3.3L V'>XTERRA 4WD V6 3.3L V</option>
                <option value='CAVALIER 4C 2.2L I-4'>CAVALIER 4C 2.2L I-4</option>
                <option value='G6 V6 3.9L V6 SFI'>G6 V6 3.9L V6 SFI</option>
                <option value='OPTIMA V6 2.7L V6 MP'>OPTIMA V6 2.7L V6 MP</option>
                <option value='GALANT V6 3.8L V6 MP'>GALANT V6 3.8L V6 MP</option>
                <option value='FOCUS 2.0L I4 MFI /'>FOCUS 2.0L I4 MFI /</option>
                <option value='RAINIER RWD V6 4.2L'>RAINIER RWD V6 4.2L</option>
                <option value='MAZDA3 2.0L I4 MFI /'>MAZDA3 2.0L I4 MFI /</option>
                <option value='SPORTAGE 2WD V6 2.7L'>SPORTAGE 2WD V6 2.7L</option>
                <option value='PILOT 3.5L V6 MPI'>PILOT 3.5L V6 MPI</option>
                <option value='SEDONA 3.8L V6 MPI'>SEDONA 3.8L V6 MPI</option>
                <option value='CAVALIER 4C 2.4L I-4'>CAVALIER 4C 2.4L I-4</option>
                <option value='RAINIER AWD V6 4.2L'>RAINIER AWD V6 4.2L</option>
                <option value='NITRO 2WD V6 3.7L V6'>NITRO 2WD V6 3.7L V6</option>
                <option value='OUTLANDER 2WD 4C'>OUTLANDER 2WD 4C</option>
                <option value='CAMARO V6'>CAMARO V6</option>
                <option value='VOYAGER FWD V6 3.3L'>VOYAGER FWD V6 3.3L</option>
                <option value='XB 1.5L I4 EFI'>XB 1.5L I4 EFI</option>
                <option value='EXPLORER 2WD V8 4.6L'>EXPLORER 2WD V8 4.6L</option>
                <option value='LE SABRE 3.8L V6 MPI'>LE SABRE 3.8L V6 MPI</option>
                <option value='TRIBUTE 2WD V6 3.0L'>TRIBUTE 2WD V6 3.0L</option>
                <option value='VERONA 2.5L I6 DI /'>VERONA 2.5L I6 DI /</option>
                <option value='ECLIPSE 2.4L I4 EFI'>ECLIPSE 2.4L I4 EFI</option>
                <option value='B3000 PICKUP 2WD V6'>B3000 PICKUP 2WD V6</option>
                <option value='GALANT 4C 2.4L I-4 E'>GALANT 4C 2.4L I-4 E</option>
                <option value='REGAL 3.8L V6 MFI'>REGAL 3.8L V6 MFI</option>
                <option value='MONTANA FWD 3.4L V6'>MONTANA FWD 3.4L V6</option>
                <option value='MAZDA3 2.3L I4 MFI /'>MAZDA3 2.3L I4 MFI /</option>
                <option value='IMPALA 3.8L V6 MFI'>IMPALA 3.8L V6 MFI</option>
                <option value='SPECTRA 2.0L I-4 EFI'>SPECTRA 2.0L I-4 EFI</option>
                <option value='STRATUS V6 3.0L V6 E'>STRATUS V6 3.0L V6 E</option>
                <option value='XTERRA 4WD V6'>XTERRA 4WD V6</option>
                <option value='CARAVAN GRAND AWD V6'>CARAVAN GRAND AWD V6</option>
                <option value='SX4'>SX4</option>
                <option value='YUKON AWD V8'>YUKON AWD V8</option>
                <option value='PATHFINDER 4WD V6'>PATHFINDER 4WD V6</option>
                <option value='CR-V 4WD'>CR-V 4WD</option>
                <option value='TUCSON 2WD V6'>TUCSON 2WD V6</option>
                <option value='COMPASS FWD 4C'>COMPASS FWD 4C</option>
                <option value='PATHFINDER 2WD V6'>PATHFINDER 2WD V6</option>
                <option value='TUCSON 4WD 4C'>TUCSON 4WD 4C</option>
                <option value='ASCENDER 4WD 6C'>ASCENDER 4WD 6C</option>
                <option value='SPECTRA 5'>SPECTRA 5</option>
                <option value='TUCSON 4WD V6'>TUCSON 4WD V6</option>
                <option value='350Z MFI V6 3.5L DOH'>350Z MFI V6 3.5L DOH</option>
                <option value='GRAND VITARA 4WD 2.7'>GRAND VITARA 4WD 2.7</option>
                <option value='CAMRY 4C 2.4L I-4 EF'>CAMRY 4C 2.4L I-4 EF</option>
                <option value='XL-7 4WD 2.7L V6 MFI'>XL-7 4WD 2.7L V6 MFI</option>
                <option value='TAURUS 3.0L V6 EFI D'>TAURUS 3.0L V6 EFI D</option>
                <option value='L SERIES 3.0L V6 EFI'>L SERIES 3.0L V6 EFI</option>
                <option value='AERIO 2.0L I4 EFI'>AERIO 2.0L I4 EFI</option>
                <option value='SEQUOIA 2WD 4.7L V8'>SEQUOIA 2WD 4.7L V8</option>
                <option value='MAZDA3 2.0L I4 MPI'>MAZDA3 2.0L I4 MPI</option>
                <option value='ALTIMA MFI V6 3.5L D'>ALTIMA MFI V6 3.5L D</option>
                <option value='TUCSON 2WD 4C 2.0L I'>TUCSON 2WD 4C 2.0L I</option>
                <option value='SPORTAGE 4WD 2.0L I4'>SPORTAGE 4WD 2.0L I4</option>
                <option value='UPLANDER AWD V6 3.5L'>UPLANDER AWD V6 3.5L</option>
                <option value='MAZDA6 3.0L V6 MPI'>MAZDA6 3.0L V6 MPI</option>
                <option value='COMMANDER 4WD V6 3.7'>COMMANDER 4WD V6 3.7</option>
                <option value='ES300 3.0L V6 EFI'>ES300 3.0L V6 EFI</option>
                <option value='ENVOY 4WD V8 5.3L V8'>ENVOY 4WD V8 5.3L V8</option>
                <option value='COUPE 1.9L I-4 SFI D'>COUPE 1.9L I-4 SFI D</option>
                <option value='PATHFINDER 4WD V6 3.'>PATHFINDER 4WD V6 3.</option>
                <option value='XTERRA 2WD 4C 2.4L I'>XTERRA 2WD 4C 2.4L I</option>
                <option value='L SERIES 2.0L I4 MPI'>L SERIES 2.0L I4 MPI</option>
                <option value='SONOMA PICKUP 2WD 4C'>SONOMA PICKUP 2WD 4C</option>
                <option value='RENO 2.0L I-4 EFI DO'>RENO 2.0L I-4 EFI DO</option>
                <option value='TUNDRA PICKUP 4WD V8'>TUNDRA PICKUP 4WD V8</option>
                <option value='CONTINENTAL 4.6L V8'>CONTINENTAL 4.6L V8</option>
                <option value='AURA 3.5L V6 SFI'>AURA 3.5L V6 SFI</option>
                <option value='MPV 2WD V6 MFI V6 3.'>MPV 2WD V6 MFI V6 3.</option>
                <option value='MONTANA AWD 3.5L V6'>MONTANA AWD 3.5L V6</option>
                <option value='MURANO AWD V6 3.5L V'>MURANO AWD V6 3.5L V</option>
                <option value='SABLE 3.0L V6 EFI 4B'>SABLE 3.0L V6 EFI 4B</option>
                <option value='CR-V 4WD 2.0L I-4 MP'>CR-V 4WD 2.0L I-4 MP</option>
                <option value='PATHFINDER 4WD V6 MF'>PATHFINDER 4WD V6 MF</option>
                <option value='ECHO Multiple Engine'>ECHO Multiple Engine</option>
                <option value='300C'>300C</option>
                <option value='SRX AWD V8 4.6L V8 S'>SRX AWD V8 4.6L V8 S</option>
                <option value='ION 2.2L I-4 MPI DOH'>ION 2.2L I-4 MPI DOH</option>
                <option value='MAXIMA 3.5L V6 MPI /'>MAXIMA 3.5L V6 MPI /</option>
                <option value='SANTA FE 2WD V6 3.5L'>SANTA FE 2WD V6 3.5L</option>
                <option value='IMPALA 3.8L V6 MFI S'>IMPALA 3.8L V6 MFI S</option>
                <option value='YUKON 4WD V8 5.3L V8'>YUKON 4WD V8 5.3L V8</option>
                <option value='VUE 2WD 4C 2.2L I-4'>VUE 2WD 4C 2.2L I-4</option>
                <option value='FOCUS 2.3L I4 DOHC'>FOCUS 2.3L I4 DOHC</option>
                <option value='TRACKER 4WD 4C'>TRACKER 4WD 4C</option>
                <option value='SOLSTICE'>SOLSTICE</option>
                <option value='ZEPHYR'>ZEPHYR</option>
                <option value='TL'>TL</option>
                <option value='YUKON 4WD V8'>YUKON 4WD V8</option>
                <option value='TRIBUTE 4WD 4C'>TRIBUTE 4WD 4C</option>
                <option value='ESCORT 2.0L I4 EFI'>ESCORT 2.0L I4 EFI</option>
                <option value='AZERA'>AZERA</option>
                <option value='626 V6'>626 V6</option>
                <option value='GRAND MARQUIS 4.6L V'>GRAND MARQUIS 4.6L V</option>
                <option value='TIBURON MFI I-4 2.0L'>TIBURON MFI I-4 2.0L</option>
                <option value='AERIO'>AERIO</option>
                <option value='ENVOY XL 4WD V8 5.3L'>ENVOY XL 4WD V8 5.3L</option>
                <option value='ES300'>ES300</option>
                <option value='ECLIPSE EI V6 3.0L S'>ECLIPSE EI V6 3.0L S</option>
                <option value='MAXIMA 3.0L V6 EFI D'>MAXIMA 3.0L V6 EFI D</option>
                <option value='STRATUS 4C 2.4L I-4'>STRATUS 4C 2.4L I-4</option>
                <option value='MOUNTAINEER AWD V8 4'>MOUNTAINEER AWD V8 4</option>
                <option value='ESCAPE 4WD 4C'>ESCAPE 4WD 4C</option>
                <option value='300C 5.7L V8 SFI / S'>300C 5.7L V8 SFI / S</option>
                <option value='EXPLORER AWD V6 4.0L'>EXPLORER AWD V6 4.0L</option>
                <option value='RX400H AWD'>RX400H AWD</option>
                <option value='VOYAGER FWD 4C 2.4L'>VOYAGER FWD 4C 2.4L</option>
                <option value='MONTERO 4WD V6 3.5L'>MONTERO 4WD V6 3.5L</option>
                <option value='PATHFINDER 2WD V6 MF'>PATHFINDER 2WD V6 MF</option>
                <option value='STRATUS V6 2.4L I-4'>STRATUS V6 2.4L I-4</option>
                <option value='FUSION V6 3.0L V6 EF'>FUSION V6 3.0L V6 EF</option>
                <option value='MONTERO 4WD V6'>MONTERO 4WD V6</option>
                <option value='SPORTAGE 2WD V6'>SPORTAGE 2WD V6</option>
                <option value='CELICA'>CELICA</option>
                <option value='MDX 4WD'>MDX 4WD</option>
                <option value='350Z'>350Z</option>
                <option value='SILHOUETTE 3.4L V6 S'>SILHOUETTE 3.4L V6 S</option>
                <option value='FOCUS 2.0L I4 SFI /'>FOCUS 2.0L I4 SFI /</option>
                <option value='GRAND AM 4C 2.2L I-4'>GRAND AM 4C 2.2L I-4</option>
                <option value='LEGACY'>LEGACY</option>
                <option value='FX35 AWD'>FX35 AWD</option>
                <option value='VENTURE FWD V6 3.5L'>VENTURE FWD V6 3.5L</option>
                <option value='VENTURE AWD V6 3.4L'>VENTURE AWD V6 3.4L</option>
                <option value='IMPREZA'>IMPREZA</option>
                <option value='DAKOTA PICKUP 2WD 4C'>DAKOTA PICKUP 2WD 4C</option>
                <option value='MAZDA3 2.3L I4 MPI'>MAZDA3 2.3L I4 MPI</option>
                <option value='MURANO 2WD V6 3.5L V'>MURANO 2WD V6 3.5L V</option>
                <option value='EXPLORER 4WD V8 4.6L'>EXPLORER 4WD V8 4.6L</option>
                <option value='B2300 PICKUP 2WD 4C'>B2300 PICKUP 2WD 4C</option>
                <option value='1500HD SIERRA PICKUP'>1500HD SIERRA PICKUP</option>
                <option value='F150 PICKUP 4WD V6'>F150 PICKUP 4WD V6</option>
                <option value='VUE 2WD V6 3.5L V6 M'>VUE 2WD V6 3.5L V6 M</option>
                <option value='CHEROKEE 2WD 6C 4.0L'>CHEROKEE 2WD 6C 4.0L</option>
                <option value='TIBURON 2.7L V6 MPI'>TIBURON 2.7L V6 MPI</option>
                <option value='HIGHLANDER 4WD V6'>HIGHLANDER 4WD V6</option>
                <option value='CAMRY V6 3.5L V6 SFI'>CAMRY V6 3.5L V6 SFI</option>
                <option value='INTREPID'>INTREPID</option>
                <option value='LS V6'>LS V6</option>
                <option value='FJ CRUISER 4WD V6'>FJ CRUISER 4WD V6</option>
                <option value='XL-7 2WD 2.7L V6 DI'>XL-7 2WD 2.7L V6 DI</option>
                <option value='F150 PICKUP 4WD V8 5'>F150 PICKUP 4WD V8 5</option>
                <option value='TRACKER 2WD V6 2.5L'>TRACKER 2WD V6 2.5L</option>
                <option value='TIBURON MFI V6 2.7L'>TIBURON MFI V6 2.7L</option>
                <option value='SIENNA 3.0L V6 MPI'>SIENNA 3.0L V6 MPI</option>
                <option value='YUKON XL 1500 4WD 5.'>YUKON XL 1500 4WD 5.</option>
                <option value='PROTEGE 5'>PROTEGE 5</option>
                <option value='CAMARO V6 3.8L V6 MF'>CAMARO V6 3.8L V6 MF</option>
                <option value='RAV-4 2WD'>RAV-4 2WD</option>
                <option value='CHEROKEE 2WD 6C'>CHEROKEE 2WD 6C</option>
                <option value='CHEROKEE 4WD 6C'>CHEROKEE 4WD 6C</option>
                <option value='MUSTANG V8'>MUSTANG V8</option>
                <option value='PRIZM'>PRIZM</option>
                <option value='300C 5.7L V8 SFI'>300C 5.7L V8 SFI</option>
                <option value='MUSTANG V8 4.6L V8 E'>MUSTANG V8 4.6L V8 E</option>
                <option value='AVIATOR 2WD V8'>AVIATOR 2WD V8</option>
                <option value='GRAND AM V6 Unspecif'>GRAND AM V6 Unspecif</option>
                <option value='PROTEGE 2.0L I-4 EFI'>PROTEGE 2.0L I-4 EFI</option>
                <option value='GRAND VITARA 2WD 2.7'>GRAND VITARA 2WD 2.7</option>
                <option value='LS V6 3.0L V6 EFI'>LS V6 3.0L V6 EFI</option>
                <option value='3.2 TL 3.2L V6 EFI'>3.2 TL 3.2L V6 EFI</option>
                <option value='TUNDRA PICKUP 2WD V6'>TUNDRA PICKUP 2WD V6</option>
                <option value='RONDO V6 2.7L V6 MPI'>RONDO V6 2.7L V6 MPI</option>
                <option value='XG 300'>XG 300</option>
                <option value='3.2 TL 3.2L V6 FI DO'>3.2 TL 3.2L V6 FI DO</option>
                <option value='RANGER PICKUP 4WD V6'>RANGER PICKUP 4WD V6</option>
                <option value='TC 2.4L I-4 EFI DOHC'>TC 2.4L I-4 EFI DOHC</option>
                <option value='PATHFINDER 4WD V6 4.'>PATHFINDER 4WD V6 4.</option>
                <option value='MONTANA AWD'>MONTANA AWD</option>
                <option value='GS300 3.0L I6 EFI'>GS300 3.0L I6 EFI</option>
                <option value='RAV-4 4WD'>RAV-4 4WD</option>
                <option value='3.2 TL'>3.2 TL</option>
                <option value='RELAY AWD V6'>RELAY AWD V6</option>
                <option value='MPV 2WD V6 MFI V6 2.'>MPV 2WD V6 MFI V6 2.</option>
                <option value='G8 V8'>G8 V8</option>
                <option value='I30'>I30</option>
                <option value='TOWN & COUNTRY AWD V'>TOWN & COUNTRY AWD V</option>
                <option value='COOPER S'>COOPER S</option>
                <option value='LIBERTY 2WD 4C 2.4L'>LIBERTY 2WD 4C 2.4L</option>
                <option value='BEETLE 2.0L I4 MPI'>BEETLE 2.0L I4 MPI</option>
                <option value='MATRIX 2WD 1.8L I-4'>MATRIX 2WD 1.8L I-4</option>
                <option value='ENVOY XL 4WD 6C 4.2L'>ENVOY XL 4WD 6C 4.2L</option>
                <option value='F250 PICKUP 2WD V8'>F250 PICKUP 2WD V8</option>
                <option value='VUE AWD 4C'>VUE AWD 4C</option>
                <option value='TITAN PICKUP 4WD V8'>TITAN PICKUP 4WD V8</option>
                <option value='M35'>M35</option>
                <option value='PILOT'>PILOT</option>
                <option value='TOUAREG V8'>TOUAREG V8</option>
                <option value='MAZDA3 2.3L I-4 MPI'>MAZDA3 2.3L I-4 MPI</option>
                <option value='ALTIMA Multiple Engi'>ALTIMA Multiple Engi</option>
                <option value='ZEPHYR 3.0L V6 SFI'>ZEPHYR 3.0L V6 SFI</option>
                <option value='COOPER S 1.6L I4 EFI'>COOPER S 1.6L I4 EFI</option>
                <option value='FOCUS 2.3L I4 MFI'>FOCUS 2.3L I4 MFI</option>
                <option value='RENDEZVOUS AWD 3.5L'>RENDEZVOUS AWD 3.5L</option>
                <option value='CAVALIER 4C 2.2L I 4'>CAVALIER 4C 2.2L I 4</option>
                <option value='FIREBIRD V6'>FIREBIRD V6</option>
                <option value='AERIO AWD'>AERIO AWD</option>
                <option value='RONDO 4C 2.4L I4 DI'>RONDO 4C 2.4L I4 DI</option>
                <option value='EDGE FWD V6'>EDGE FWD V6</option>
                <option value='EDGE AWD V6'>EDGE AWD V6</option>
                <option value='I-370 PICKUP 2WD 5C'>I-370 PICKUP 2WD 5C</option>
                <option value='ION 2.2L I-4 EFI DOH'>ION 2.2L I-4 EFI DOH</option>
                <option value='XG 300 Unspecified'>XG 300 Unspecified</option>
                <option value='SUNFIRE 2.2L I-4 MPI'>SUNFIRE 2.2L I-4 MPI</option>
                <option value='300M 3.5L V6 MPI HO'>300M 3.5L V6 MPI HO</option>
                <option value='VERONA 2.5L I-6 MPI'>VERONA 2.5L I-6 MPI</option>
                <option value='MAZDA6 3.0L V6 MPI D'>MAZDA6 3.0L V6 MPI D</option>
                <option value='XTERRA 2WD V6 4.0L V'>XTERRA 2WD V6 4.0L V</option>
                <option value='626 4C'>626 4C</option>
                <option value='VUE AWD V6 3.5L V6 M'>VUE AWD V6 3.5L V6 M</option>
                <option value='XL-7 2WD 2.7L V6 MFI'>XL-7 2WD 2.7L V6 MFI</option>
                <option value='3.2 CL 3.2L V 6 NA S'>3.2 CL 3.2L V 6 NA S</option>
                <option value='INTREPID 2.7L V6 SFI'>INTREPID 2.7L V6 SFI</option>
                <option value='ECLIPSE 3.0L V6 EFI'>ECLIPSE 3.0L V6 EFI</option>
                <option value='CR-V 2WD 2.0L I 4 NA'>CR-V 2WD 2.0L I 4 NA</option>
                <option value='ESCALADE 2WD'>ESCALADE 2WD</option>
                <option value='ESCORT 2.0L I-4 EFI'>ESCORT 2.0L I-4 EFI</option>
                <option value='CROWN VICTORIA 4.6L'>CROWN VICTORIA 4.6L</option>
                <option value='ACCENT 1.6L I-4 MPI'>ACCENT 1.6L I-4 MPI</option>
                <option value='STRATUS V6 2.7L V6 S'>STRATUS V6 2.7L V6 S</option>
                <option value='SABLE 3.0L V6 EFI 2B'>SABLE 3.0L V6 EFI 2B</option>
                <option value='LANCER 2.0L I-4 MPI'>LANCER 2.0L I-4 MPI</option>
                <option value='VUE AWD V6 3.0L V6 S'>VUE AWD V6 3.0L V6 S</option>
                <option value='GRAND AM 4C 2.4L I-4'>GRAND AM 4C 2.4L I-4</option>
                <option value='COOPER 1.6L I-4 EFI'>COOPER 1.6L I-4 EFI</option>
                <option value='LS V6 3.0L V6 EFI DO'>LS V6 3.0L V6 EFI DO</option>
                <option value='OUTBACK'>OUTBACK</option>
                <option value='MURANO AWD V6'>MURANO AWD V6</option>
                <option value='NAVIGATOR 2WD V8'>NAVIGATOR 2WD V8</option>
                <option value='4 RUNNER 4WD V6'>4 RUNNER 4WD V6</option>
                <option value='HHR 2.4L I4 MPI / SF'>HHR 2.4L I4 MPI / SF</option>
                <option value='RAIDER 2WD V6'>RAIDER 2WD V6</option>
                <option value='ELEMENT 2WD 2.4L I-4'>ELEMENT 2WD 2.4L I-4</option>
                <option value='ARMADA 2WD V8'>ARMADA 2WD V8</option>
                <option value='MALIBU HYBRID'>MALIBU HYBRID</option>
                <option value='YUKON 2WD V8 5.3L V8'>YUKON 2WD V8 5.3L V8</option>
                <option value='TSX'>TSX</option>
                <option value='626 4C 2.0L I-4 EFI'>626 4C 2.0L I-4 EFI</option>
                <option value='626 4C 2.0L I4 EFI'>626 4C 2.0L I4 EFI</option>
                <option value='FOCUS 2.3L I4 SFI'>FOCUS 2.3L I4 SFI</option>
                <option value='ESCORT 2.0L I-4 SPI'>ESCORT 2.0L I-4 SPI</option>
                <option value='COUPE'>COUPE</option>
                <option value='SENTRA 1.8L I 4 NA D'>SENTRA 1.8L I 4 NA D</option>
                <option value='SEDONA 3.5L V6 EFI'>SEDONA 3.5L V6 EFI</option>
                <option value='ESCORT 4-FI-2.0L'>ESCORT 4-FI-2.0L</option>
                <option value='OPTIMA 4C 2.4L I 4 N'>OPTIMA 4C 2.4L I 4 N</option>
                <option value='COUPE 1.9L I-4 SFI S'>COUPE 1.9L I-4 SFI S</option>
                <option value='VERONA'>VERONA</option>
                <option value='S10 PICKUP 2WD V6 4.'>S10 PICKUP 2WD V6 4.</option>
                <option value='GRAND VITARA 4WD'>GRAND VITARA 4WD</option>
                <option value='VIBE AWD'>VIBE AWD</option>
                <option value='TRAILBLAZER 2WD V8'>TRAILBLAZER 2WD V8</option>
                <option value='ACCORD 4C 2.3L I-4 E'>ACCORD 4C 2.3L I-4 E</option>
                <option value='4 RUNNER 4WD V6 3.4L'>4 RUNNER 4WD V6 3.4L</option>
                <option value='CANYON PICKUP 2WD 4C'>CANYON PICKUP 2WD 4C</option>
                <option value='GX470 4WD'>GX470 4WD</option>
                <option value='SIENNA'>SIENNA</option>
                <option value='MOUNTAINEER 2WD V6 4'>MOUNTAINEER 2WD V6 4</option>
                <option value='AVIATOR 2WD V8 4.6L'>AVIATOR 2WD V8 4.6L</option>
                <option value='LIBERTY 4WD 4C'>LIBERTY 4WD 4C</option>
                <option value='MARINER 2WD 4C'>MARINER 2WD 4C</option>
                <option value='G35 3.5L V6 SMPI'>G35 3.5L V6 SMPI</option>
                <option value='AXIOM 2WD V6'>AXIOM 2WD V6</option>
                <option value='IMPALA V6 3.9L V6 SF'>IMPALA V6 3.9L V6 SF</option>
                <option value='MAZDA5 2.3L I4 MFI /'>MAZDA5 2.3L I4 MFI /</option>
                <option value='S10 PICKUP 4WD V6'>S10 PICKUP 4WD V6</option>
                <option value='COOPER 1.6L I4 EFI'>COOPER 1.6L I4 EFI</option>
                <option value='HHR 2.4L I4 MPI'>HHR 2.4L I4 MPI</option>
                <option value='CTS 3.6L V6 SFI'>CTS 3.6L V6 SFI</option>
                <option value='4 RUNNER 2WD V6'>4 RUNNER 2WD V6</option>
                <option value='F150 PICKUP 4WD V8 4'>F150 PICKUP 4WD V8 4</option>
                <option value='TAURUS X AWD V6'>TAURUS X AWD V6</option>
                <option value='DURANGO 4WD V8 5.9L'>DURANGO 4WD V8 5.9L</option>
                <option value='RX330 FWD'>RX330 FWD</option>
                <option value='RSX'>RSX</option>
                <option value='M35 3.5L V6 MPI'>M35 3.5L V6 MPI</option>
                <option value='LS V8 3.9L V8 EFI'>LS V8 3.9L V8 EFI</option>
                <option value='MONTANA 3.4L V 6 NA'>MONTANA 3.4L V 6 NA</option>
                <option value='CX-7 FWD 4C'>CX-7 FWD 4C</option>
                <option value='EXCURSION 4WD V8 5.4'>EXCURSION 4WD V8 5.4</option>
                <option value='TC'>TC</option>
                <option value='HIGHLANDER 4WD 4C'>HIGHLANDER 4WD 4C</option>
                <option value='DURANGO 2WD V8 5.9L'>DURANGO 2WD V8 5.9L</option>
                <option value='ENVOY 4WD 6C 4.2L I-'>ENVOY 4WD 6C 4.2L I-</option>
                <option value='G35 3.5L V6 MPI'>G35 3.5L V6 MPI</option>
            <h3>What Is the submodel type?</h3><br><select name="SubModel_encoded" id="fuel" required="required">
                <option value='4D SEDAN I'>4D SEDAN I</option>
                <option value='QUAD CAB 4.7L SLT'>QUAD CAB 4.7L SLT</option>
                <option value='4D SEDAN SXT FFV'>4D SEDAN SXT FFV</option>
                <option value='4D SEDAN'>4D SEDAN</option>
                <option value='2D COUPE ZX3'>2D COUPE ZX3</option>
                <option value='4D SEDAN ES'>4D SEDAN ES</option>
                <option value='4D SEDAN EX'>4D SEDAN EX</option>
                <option value='4D SEDAN SE'>4D SEDAN SE</option>
                <option value='4D SEDAN SEL'>4D SEDAN SEL</option>
                <option value='REG CAB 4.3L'>REG CAB 4.3L</option>
                <option value='REG CAB 4.2L XL'>REG CAB 4.2L XL</option>
                <option value='MINIVAN 3.3L'>MINIVAN 3.3L</option>
                <option value='MINIVAN 3.8L'>MINIVAN 3.8L</option>
                <option value='2D COUPE'>2D COUPE</option>
                <option value='4D SUV 4.2L'>4D SUV 4.2L</option>
                <option value='4D CUV 2.2L'>4D CUV 2.2L</option>
                <option value='4D UTILITY 4.2L SLE'>4D UTILITY 4.2L SLE</option>
                <option value='2D COUPE SS'>2D COUPE SS</option>
                <option value='PASSENGER 3.4L'>PASSENGER 3.4L</option>
                <option value='4D SUV 2.2L LS'>4D SUV 2.2L LS</option>
                <option value='4D SEDAN LS PREMIUM'>4D SEDAN LS PREMIUM</option>
                <option value='4D SUV 5.7L SLT'>4D SUV 5.7L SLT</option>
                <option value='MINIVAN 3.8L SXT'>MINIVAN 3.8L SXT</option>
                <option value='4D UTILITY 5.3L FFV LS'>4D UTILITY 5.3L FFV LS</option>
                <option value='2D SUV 4.0L SPORT'>2D SUV 4.0L SPORT</option>
                <option value='4D SUV-PICKUP 5.3L'>4D SUV-PICKUP 5.3L</option>
                <option value='PASSENGER 3.8L LX'>PASSENGER 3.8L LX</option>
                <option value='PASSENGER 3.9L LX'>PASSENGER 3.9L LX</option>
                <option value='4D WAGON SXT'>4D WAGON SXT</option>
                <option value='4D SEDAN 1.8'>4D SEDAN 1.8</option>
                <option value='4D SPORT TOURER'>4D SPORT TOURER</option>
                <option value='4D SEDAN LS 3.5L FFV'>4D SEDAN LS 3.5L FFV</option>
                <option value='QUAD CAB 5.7L'>QUAD CAB 5.7L</option>
                <option value='4D SPORT UTILITY'>4D SPORT UTILITY</option>
                <option value='4D SEDAN CE'>4D SEDAN CE</option>
                <option value='4D SEDAN GT'>4D SEDAN GT</option>
                <option value='QUAD CAB 4.7L'>QUAD CAB 4.7L</option>
                <option value='4D SEDAN LEVEL 2'>4D SEDAN LEVEL 2</option>
                <option value='4D SUV 4.7L'>4D SUV 4.7L</option>
                <option value='4D SUV 4.7L ADVENTURER'>4D SUV 4.7L ADVENTURER</option>
                <option value='4D SEDAN GLS'>4D SEDAN GLS</option>
                <option value='4D SPORT UTILITY SPORT EDITION'>4D SPORT UTILITY SPORT EDITION</option>
                <option value='4D SEDAN GXP'>4D SEDAN GXP</option>
                <option value='4D WAGON SPORT'>4D WAGON SPORT</option>
                <option value='4D SUV'>4D SUV</option>
                <option value='QUAD CAB 3.7L ST'>QUAD CAB 3.7L ST</option>
                <option value='4D SUV 5.3L'>4D SUV 5.3L</option>
                <option value='4D SEDAN LS'>4D SEDAN LS</option>
                <option value='4D SUV 4.6L XLT'>4D SUV 4.6L XLT</option>
                <option value='4D SUV 4.7L ST'>4D SUV 4.7L ST</option>
                <option value='4D SPORT UTILITY EX'>4D SPORT UTILITY EX</option>
                <option value='4D SUV 2.2L LT'>4D SUV 2.2L LT</option>
                <option value='4D SEDAN SES'>4D SEDAN SES</option>
                <option value='4D CUV 3.0L SEL'>4D CUV 3.0L SEL</option>
                <option value='CREW CAB 5.4L KING RANCH'>CREW CAB 5.4L KING RANCH</option>
                <option value='4D SUV 4.2L LS'>4D SUV 4.2L LS</option>
                <option value='4D SUV HARDTOP 2.5L LT'>4D SUV HARDTOP 2.5L LT</option>
                <option value='QUAD CAB 5.7L SLT'>QUAD CAB 5.7L SLT</option>
                <option value='4D SUV 3.7L'>4D SUV 3.7L</option>
                <option value='4D SUV 4.6L XLS'>4D SUV 4.6L XLS</option>
                <option value='QUAD CAB 4.7L FFV BIG HORN'>QUAD CAB 4.7L FFV BIG HORN</option>
                <option value='4D SEDAN GL1'>4D SEDAN GL1</option>
                <option value='MINIVAN 3.3L LX'>MINIVAN 3.3L LX</option>
                <option value='4D SEDAN LE'>4D SEDAN LE</option>
                <option value='WAGON 2.7L'>WAGON 2.7L</option>
                <option value='4D SUV LS'>4D SUV LS</option>
                <option value='4D SUV SPORT'>4D SUV SPORT</option>
                <option value='4D SEDAN LEVEL 1'>4D SEDAN LEVEL 1</option>
                <option value='4D CUV 3.0L SE'>4D CUV 3.0L SE</option>
                <option value='4D SEDAN L200'>4D SEDAN L200</option>
                <option value='4D SUV LIMITED'>4D SUV LIMITED</option>
                <option value='4D WAGON'>4D WAGON</option>
                <option value='5D SEDAN GS'>5D SEDAN GS</option>
                <option value='4D SUV 4.6L EDDIE BAUER'>4D SUV 4.6L EDDIE BAUER</option>
                <option value='4D SUV 5.4L EDDIE BAUER'>4D SUV 5.4L EDDIE BAUER</option>
                <option value='REG CAB 3.7L'>REG CAB 3.7L</option>
                <option value='4D MINIVAN EXT 3.4L GLS'>4D MINIVAN EXT 3.4L GLS</option>
                <option value='4D CUV 3.0L XLT'>4D CUV 3.0L XLT</option>
                <option value='4D SEDAN LEVEL 3'>4D SEDAN LEVEL 3</option>
                <option value='2D EXT CAB 3.0L EDGE'>2D EXT CAB 3.0L EDGE</option>
                <option value='4D WAGON ZTW'>4D WAGON ZTW</option>
                <option value='2D COUPE LS'>2D COUPE LS</option>
                <option value='4D SUV 4.7L SLT'>4D SUV 4.7L SLT</option>
                <option value='PASSENGER EXT 3.5L'>PASSENGER EXT 3.5L</option>
                <option value='EXT CAB 4.8L'>EXT CAB 4.8L</option>
                <option value='4D SUV 4.0L FFV XLT'>4D SUV 4.0L FFV XLT</option>
                <option value='4D SPORT UTILITY LS'>4D SPORT UTILITY LS</option>
                <option value='4D SEDAN SEL FFV'>4D SEDAN SEL FFV</option>
                <option value='4D SEDAN SE FFV'>4D SEDAN SE FFV</option>
                <option value='WAGON 3.5L'>WAGON 3.5L</option>
                <option value='4D SPORT TOURING'>4D SPORT TOURING</option>
                <option value='4D SEDAN ZX4 SE'>4D SEDAN ZX4 SE</option>
                <option value='4D SEDAN GL'>4D SEDAN GL</option>
                <option value='4D SEDAN LT 3.5L'>4D SEDAN LT 3.5L</option>
                <option value='4D CUV'>4D CUV</option>
                <option value='4D SEDAN S'>4D SEDAN S</option>
                <option value='EXT CAB 3.7L'>EXT CAB 3.7L</option>
                <option value='PASSENGER EXT 3.5L LS'>PASSENGER EXT 3.5L LS</option>
                <option value='REG CAB 3.0L EDGE'>REG CAB 3.0L EDGE</option>
                <option value='MINIVAN 3.3L FFV SPORT'>MINIVAN 3.3L FFV SPORT</option>
                <option value='4D SPORT UTILITY I'>4D SPORT UTILITY I</option>
                <option value='4D SUV CX'>4D SUV CX</option>
                <option value='4D SEDAN LT 3.5L FFV'>4D SEDAN LT 3.5L FFV</option>
                <option value='REG CAB 4.2L STX'>REG CAB 4.2L STX</option>
                <option value='4D SEDAN SE1'>4D SEDAN SE1</option>
                <option value='4D WAGON SE'>4D WAGON SE</option>
                <option value='4D SEDAN LX AUTO'>4D SEDAN LX AUTO</option>
                <option value='4D CUV 2.3L XLS'>4D CUV 2.3L XLS</option>
                <option value='2D COUPE SE'>2D COUPE SE</option>
                <option value='4D SEDAN ZX4'>4D SEDAN ZX4</option>
                <option value='REG CAB 2.8L'>REG CAB 2.8L</option>
                <option value='4D CUV 2.7L'>4D CUV 2.7L</option>
                <option value='4D WAGON LAREDO'>4D WAGON LAREDO</option>
                <option value='4D SEDAN SE COMFORT'>4D SEDAN SE COMFORT</option>
                <option value='4D SEDAN LX'>4D SEDAN LX</option>
                <option value='MINIVAN 3.3L SPORT'>MINIVAN 3.3L SPORT</option>
                <option value='4D SEDAN 2.7L SE'>4D SEDAN 2.7L SE</option>
                <option value='4D SPORT'>4D SPORT</option>
                <option value='4D SEDAN SXT'>4D SEDAN SXT</option>
                <option value='4D SEDAN GS'>4D SEDAN GS</option>
                <option value='4D SUV HARDTOP 2.5L'>4D SUV HARDTOP 2.5L</option>
                <option value='4D SEDAN LT'>4D SEDAN LT</option>
                <option value='4D SPORT UTILITY SE'>4D SPORT UTILITY SE</option>
                <option value='4D SEDAN XE'>4D SEDAN XE</option>
                <option value='REG CAB 4.6L STX'>REG CAB 4.6L STX</option>
                <option value='4D SPORT UTILITY S'>4D SPORT UTILITY S</option>
                <option value='EXT CAB 4.6L STX'>EXT CAB 4.6L STX</option>
                <option value='4D WAGON CX'>4D WAGON CX</option>
                <option value='4D SUV RENEGADE'>4D SUV RENEGADE</option>
                <option value='MINIVAN 3.3L SE'>MINIVAN 3.3L SE</option>
                <option value='4D SEDAN TOURING TURBO'>4D SEDAN TOURING TURBO</option>
                <option value='2D CONVERTIBLE LX'>2D CONVERTIBLE LX</option>
                <option value='4D SEDAN LTZ'>4D SEDAN LTZ</option>
                <option value='PASSENGER 3.5L LS'>PASSENGER 3.5L LS</option>
                <option value='4D CUV 2.7L GLS'>4D CUV 2.7L GLS</option>
                <option value='4D SEDAN ZTS'>4D SEDAN ZTS</option>
                <option value='4D HATCHBACK S'>4D HATCHBACK S</option>
                <option value='4D SUV 4.0L FFV XLS'>4D SUV 4.0L FFV XLS</option>
                <option value='MINIVAN 3.8L SPORT'>MINIVAN 3.8L SPORT</option>
                <option value='4D SUV 3.7L SLT'>4D SUV 3.7L SLT</option>
                <option value='EXT CAB 4.6L FX2 SPORT'>EXT CAB 4.6L FX2 SPORT</option>
                <option value='4D SEDAN PKG1'>4D SEDAN PKG1</option>
                <option value='2D CONVERTIBLE GTC'>2D CONVERTIBLE GTC</option>
                <option value='4D SEDAN LT 3.9L'>4D SEDAN LT 3.9L</option>
                <option value='MAZDA3 4D I SPORT'>MAZDA3 4D I SPORT</option>
                <option value='4D PASSENGER 3.8L SE'>4D PASSENGER 3.8L SE</option>
                <option value='4D SEDAN GTP'>4D SEDAN GTP</option>
                <option value='4D SEDAN LS SPORT'>4D SEDAN LS SPORT</option>
                <option value='PASSENGER EXT 3.4L LS'>PASSENGER EXT 3.4L LS</option>
                <option value='4D SUV 5.4L XLT'>4D SUV 5.4L XLT</option>
                <option value='4D SEDAN 2.7L'>4D SEDAN 2.7L</option>
                <option value='4D SEDAN CLASSIC'>4D SEDAN CLASSIC</option>
                <option value='4D SUV 3.0L'>4D SUV 3.0L</option>
                <option value='2D CONVERTIBLE TOURING'>2D CONVERTIBLE TOURING</option>
                <option value='4D SEDAN TOURING'>4D SEDAN TOURING</option>
                <option value='SPORT UTILITY'>SPORT UTILITY</option>
                <option value='2D SPYDER GT'>2D SPYDER GT</option>
                <option value='4D SUV LT'>4D SUV LT</option>
                <option value='4D SEDAN LXI'>4D SEDAN LXI</option>
                <option value='PASSENGER EXT 3.4L'>PASSENGER EXT 3.4L</option>
                <option value='4D SEDAN SE-R'>4D SEDAN SE-R</option>
                <option value='MINIVAN 3.8L LXI'>MINIVAN 3.8L LXI</option>
                <option value='EXT CAB 5.3L LS'>EXT CAB 5.3L LS</option>
                <option value='4D SUV 4.8L LS'>4D SUV 4.8L LS</option>
                <option value='4D SEDAN GT2'>4D SEDAN GT2</option>
                <option value='4D SPORT UTILITY LX'>4D SPORT UTILITY LX</option>
                <option value='2D COUPE LT'>2D COUPE LT</option>
                <option value='4D SUV 4.0L XLT'>4D SUV 4.0L XLT</option>
                <option value='2D COUPE EX AUTO'>2D COUPE EX AUTO</option>
                <option value='4D CUV 3.0L XLS'>4D CUV 3.0L XLS</option>
                <option value='2D COUPE GS'>2D COUPE GS</option>
                <option value='4D SEDAN EXECUTIVE'>4D SEDAN EXECUTIVE</option>
                <option value='4D SEDAN PREMIER'>4D SEDAN PREMIER</option>
                <option value='4D SEDAN EX AUTO'>4D SEDAN EX AUTO</option>
                <option value='4D SUV 5.7L LIMITED'>4D SUV 5.7L LIMITED</option>
                <option value='MINIVAN 2.4L'>MINIVAN 2.4L</option>
                <option value='4D SEDAN LIMITED'>4D SEDAN LIMITED</option>
                <option value='CREW CAB 5.3L'>CREW CAB 5.3L</option>
                <option value='4D SEDAN SL2'>4D SEDAN SL2</option>
                <option value='4D PASSENGER 3.8L SEL'>4D PASSENGER 3.8L SEL</option>
                <option value='4D SEDAN GXE'>4D SEDAN GXE</option>
                <option value='4D SEDAN SE AUTO'>4D SEDAN SE AUTO</option>
                <option value='4D SEDAN ES HIGHLINE'>4D SEDAN ES HIGHLINE</option>
                <option value='4D SUV 5.9L SLT'>4D SUV 5.9L SLT</option>
                <option value='EXT CAB 5.3L'>EXT CAB 5.3L</option>
                <option value='PASSENGER 3.9L'>PASSENGER 3.9L</option>
                <option value='4D SEDAN SL1'>4D SEDAN SL1</option>
                <option value='4D SEDAN CUSTOM'>4D SEDAN CUSTOM</option>
                <option value='QUAD CAB 3.7L'>QUAD CAB 3.7L</option>
                <option value='4D SPORT UTILITY ES'>4D SPORT UTILITY ES</option>
                <option value='4D SEDAN LUXURY'>4D SEDAN LUXURY</option>
                <option value='REG CAB 2.2L FFV'>REG CAB 2.2L FFV</option>
                <option value='4D SEDAN SES DURATEC'>4D SEDAN SES DURATEC</option>
                <option value='CREW CAB 4.6L XLT'>CREW CAB 4.6L XLT</option>
                <option value='4D SEDAN DE'>4D SEDAN DE</option>
                <option value='4D SEDAN GL2'>4D SEDAN GL2</option>
                <option value='4D SUV 5.3L FFV LS'>4D SUV 5.3L FFV LS</option>
                <option value='4D SEDAN 1.8S'>4D SEDAN 1.8S</option>
                <option value='2D COUPE SE AUTO'>2D COUPE SE AUTO</option>
                <option value='4D SEDAN 3.5L'>4D SEDAN 3.5L</option>
                <option value='2D HATCKBACK SI 5SP'>2D HATCKBACK SI 5SP</option>
                <option value='WAGON 3.5L SXT'>WAGON 3.5L SXT</option>
                <option value='4D SEDAN CX'>4D SEDAN CX</option>
                <option value='2D QUAD COUPE LEVEL 3'>2D QUAD COUPE LEVEL 3</option>
                <option value='4D SEDAN GLE'>4D SEDAN GLE</option>
                <option value='2D CONVERTIBLE'>2D CONVERTIBLE</option>
                <option value='4D SEDAN 3.5L SE'>4D SEDAN 3.5L SE</option>
                <option value='MINIVAN 3.3L SXT'>MINIVAN 3.3L SXT</option>
                <option value='4D SPORT UTILITY 2.5X'>4D SPORT UTILITY 2.5X</option>
                <option value='4D SPORT UTILITY XE'>4D SPORT UTILITY XE</option>
                <option value='EXT CAB 4.7L SLT'>EXT CAB 4.7L SLT</option>
                <option value='2D COUPE GT1'>2D COUPE GT1</option>
                <option value='2D CONVERTIBLE SE'>2D CONVERTIBLE SE</option>
                <option value='4D MINIVAN EXT 3.4L'>4D MINIVAN EXT 3.4L</option>
                <option value='4D HATCHBACK GS'>4D HATCHBACK GS</option>
                <option value='4D SUV 5.3L LS'>4D SUV 5.3L LS</option>
                <option value='EXT CAB 4.3L'>EXT CAB 4.3L</option>
                <option value='4D UTILITY 4.2L'>4D UTILITY 4.2L</option>
                <option value='MINIVAN 3.8L EX'>MINIVAN 3.8L EX</option>
                <option value='4D SEDAN XR'>4D SEDAN XR</option>
                <option value='REG CAB 2.3L EDGE'>REG CAB 2.3L EDGE</option>
                <option value='4D SEDAN LT 3.8L FFV'>4D SEDAN LT 3.8L FFV</option>
                <option value='2D COUPE GT'>2D COUPE GT</option>
                <option value='2D CONVERTIBLE DREAM CRUISER'>2D CONVERTIBLE DREAM CRUISER</option>
                <option value='4D PASSENGER 3.9L SES'>4D PASSENGER 3.9L SES</option>
                <option value='2D COUPE SVT'>2D COUPE SVT</option>
                <option value='MINIVAN 3.3L FFV SE'>MINIVAN 3.3L FFV SE</option>
                <option value='4D CUV 3.0L LIMITED'>4D CUV 3.0L LIMITED</option>
                <option value='4D SUV 4.0L'>4D SUV 4.0L</option>
                <option value='QUAD CAB 4.7L SPORT'>QUAD CAB 4.7L SPORT</option>
                <option value='2D COUPE GLS'>2D COUPE GLS</option>
                <option value='4D WAGON LW300'>4D WAGON LW300</option>
                <option value='REG CAB 3.9L'>REG CAB 3.9L</option>
                <option value='4D SEDAN LS CLASSIC'>4D SEDAN LS CLASSIC</option>
                <option value='EXT MINIVAN 3.3L LX'>EXT MINIVAN 3.3L LX</option>
                <option value='EXT CAB 5.4L XL'>EXT CAB 5.4L XL</option>
                <option value='4D SUV 4.0L XLS'>4D SUV 4.0L XLS</option>
                <option value='2D QUAD COUPE LEVEL 2'>2D QUAD COUPE LEVEL 2</option>
                <option value='2D COUPE GL2'>2D COUPE GL2</option>
                <option value='4D HARDTOP EX'>4D HARDTOP EX</option>
                <option value='4D SUV 4.8L'>4D SUV 4.8L</option>
                <option value='EXT CAB 5.3L SLE'>EXT CAB 5.3L SLE</option>
                <option value='EXT CAB 4.8L LS'>EXT CAB 4.8L LS</option>
                <option value='EXT CAB 4.6L XLT'>EXT CAB 4.6L XLT</option>
                <option value='CREW CAB 5.6L SE'>CREW CAB 5.6L SE</option>
                <option value='4D SUV 2.2L 1LT'>4D SUV 2.2L 1LT</option>
                <option value='4D MINIVAN EXT 3.5L'>4D MINIVAN EXT 3.5L</option>
                <option value='4D SEDAN LS 3.5L'>4D SEDAN LS 3.5L</option>
                <option value='2D COUPE SXT'>2D COUPE SXT</option>
                <option value='4D SUV 4.2L LT'>4D SUV 4.2L LT</option>
                <option value='4D WAGON LX'>4D WAGON LX</option>
                <option value='REG CAB 4.7L SLT'>REG CAB 4.7L SLT</option>
                <option value='4D WAGON GT'>4D WAGON GT</option>
                <option value='CARGO EXT 3.9L'>CARGO EXT 3.9L</option>
                <option value='4D SEDAN VALUE'>4D SEDAN VALUE</option>
                <option value='EXT CAB 5.6L'>EXT CAB 5.6L</option>
                <option value='2D COUPE GTP'>2D COUPE GTP</option>
                <option value='EXT CAB 5.4L XLT'>EXT CAB 5.4L XLT</option>
                <option value='REG CAB 4.7L'>REG CAB 4.7L</option>
                <option value='PASSENGER 3.9L SE'>PASSENGER 3.9L SE</option>
                <option value='2D COUPE GL'>2D COUPE GL</option>
                <option value='4D CUV 3.0L'>4D CUV 3.0L</option>
                <option value='UTILITY'>UTILITY</option>
                <option value='4D SEDAN LIMITED AWD'>4D SEDAN LIMITED AWD</option>
                <option value='4D SEDAN GT1'>4D SEDAN GT1</option>
                <option value='4D CUV GLS'>4D CUV GLS</option>
                <option value='4D SUV HARDTOP 2.0L'>4D SUV HARDTOP 2.0L</option>
                <option value='MINIVAN 2.4L SE'>MINIVAN 2.4L SE</option>
                <option value='QUAD CAB 3.9L SLT'>QUAD CAB 3.9L SLT</option>
                <option value='EXT CAB 3.9L'>EXT CAB 3.9L</option>
                <option value='EXT CAB 5.4L LARIAT'>EXT CAB 5.4L LARIAT</option>
                <option value='4D WAGON LS PREMIUM'>4D WAGON LS PREMIUM</option>
                <option value='4D SEDAN CARTIER'>4D SEDAN CARTIER</option>
                <option value='EXT CAB 4.7L LIMITED'>EXT CAB 4.7L LIMITED</option>
                <option value='MINIVAN 3.8L EL'>MINIVAN 3.8L EL</option>
                <option value='4D WAGON SEL DURATEC'>4D WAGON SEL DURATEC</option>
                <option value='4D SPORT UTILITY 5 PASS'>4D SPORT UTILITY 5 PASS</option>
                <option value='EXT CAB 2.4L XE'>EXT CAB 2.4L XE</option>
                <option value='EXT CAB 3.5L LS'>EXT CAB 3.5L LS</option>
                <option value='WAGON ES'>WAGON ES</option>
                <option value='MINIVAN 3.3L LX POPULAR'>MINIVAN 3.3L LX POPULAR</option>
                <option value='4D WAGON LIMITED'>4D WAGON LIMITED</option>
                <option value='4D CUV DLX'>4D CUV DLX</option>
                <option value='REG CAB 5.7L ST'>REG CAB 5.7L ST</option>
                <option value='4D SEDAN SPECIAL'>4D SEDAN SPECIAL</option>
                <option value='REG CAB 4.6L XLT'>REG CAB 4.6L XLT</option>
                <option value='4D SEDAN CXL'>4D SEDAN CXL</option>
                <option value='4D SEDAN SE SVG'>4D SEDAN SE SVG</option>
                <option value='4D SUV 4.0L SPORT TRAC'>4D SUV 4.0L SPORT TRAC</option>
                <option value='PASSENGER 3.4L VALUE'>PASSENGER 3.4L VALUE</option>
                <option value='CREW CAB 5.4L HARLEY DAVIDSON'>CREW CAB 5.4L HARLEY DAVIDSON</option>
                <option value='4D CUV 2.0L XLS'>4D CUV 2.0L XLS</option>
                <option value='4D SPORTBACK LS'>4D SPORTBACK LS</option>
                <option value='MINIVAN 3.3L EL'>MINIVAN 3.3L EL</option>
                <option value='REG CAB 2.4L'>REG CAB 2.4L</option>
                <option value='4D WAGON LW200'>4D WAGON LW200</option>
                <option value='4D SPORT UTILITY XLS'>4D SPORT UTILITY XLS</option>
                <option value='2D SEDAN'>2D SEDAN</option>
                <option value='PASSENGER 3.8L'>PASSENGER 3.8L</option>
                <option value='REG CAB 3.5L LS'>REG CAB 3.5L LS</option>
                <option value='4D SUV 4.7L SPORT'>4D SUV 4.7L SPORT</option>
                <option value='4D EXT CAB 3.0L FFV XLT'>4D EXT CAB 3.0L FFV XLT</option>
                <option value='4D CUV 3.5L'>4D CUV 3.5L</option>
                <option value='MINIVAN 2.4L LX'>MINIVAN 2.4L LX</option>
                <option value='PASSENGER 3.9L SEL'>PASSENGER 3.9L SEL</option>
                <option value='REG CAB 2.3L'>REG CAB 2.3L</option>
                <option value='4D SEDAN L300'>4D SEDAN L300</option>
                <option value='4D MINIVAN 3.4L'>4D MINIVAN 3.4L</option>
                <option value='4D SUV 3.7L SXT'>4D SUV 3.7L SXT</option>
                <option value='4D SUV CXL'>4D SUV CXL</option>
                <option value='4D SEDAN SE COMFORT DURATEC'>4D SEDAN SE COMFORT DURATEC</option>
                <option value='WAGON R/T'>WAGON R/T</option>
                <option value='4D SEDAN ZX4 SES'>4D SEDAN ZX4 SES</option>
                <option value='QUAD CAB 3.7L SLT'>QUAD CAB 3.7L SLT</option>
                <option value='4D SEDAN 3.5L AWD'>4D SEDAN 3.5L AWD</option>
                <option value='REG CAB 4.8L LS'>REG CAB 4.8L LS</option>
                <option value='4D SEDAN CXS'>4D SEDAN CXS</option>
                <option value='PASSENGER EXT 3.9L LS'>PASSENGER EXT 3.9L LS</option>
                <option value='QUAD CAB 3.7L SPORT'>QUAD CAB 3.7L SPORT</option>
                <option value='PASSENGER EXT 3.5L LT'>PASSENGER EXT 3.5L LT</option>
                <option value='4D SUV 4.7L SXT'>4D SUV 4.7L SXT</option>
                <option value='4D SUV 5.7L'>4D SUV 5.7L</option>
                <option value='EXT CAB 4.3L LS'>EXT CAB 4.3L LS</option>
                <option value='4D SEDAN AWD SE'>4D SEDAN AWD SE</option>
                <option value='4D SEDAN DX AUTO'>4D SEDAN DX AUTO</option>
                <option value='4D SEDAN LX 5SP'>4D SEDAN LX 5SP</option>
                <option value='4D SEDAN SE AWD'>4D SEDAN SE AWD</option>
                <option value='4D WAGON CINCO'>4D WAGON CINCO</option>
                <option value='4D SEDAN PREMIER AWD'>4D SEDAN PREMIER AWD</option>
                <option value='EXT CAB 5.4L FX2 SPORT'>EXT CAB 5.4L FX2 SPORT</option>
                <option value='QUAD CAB 5.7L BIG HORN'>QUAD CAB 5.7L BIG HORN</option>
                <option value='4D SUV 4.7L FFV SXT'>4D SUV 4.7L FFV SXT</option>
                <option value='4D UTILITY 5.3L SLE'>4D UTILITY 5.3L SLE</option>
                <option value='4D WAGON EX'>4D WAGON EX</option>
                <option value='PASSENGER 4.2L SE'>PASSENGER 4.2L SE</option>
                <option value='CREW CAB 5.4L LARIAT'>CREW CAB 5.4L LARIAT</option>
                <option value='4D SEDAN GT TURBO'>4D SEDAN GT TURBO</option>
                <option value='4D SPORT UTILITY LE'>4D SPORT UTILITY LE</option>
                <option value='2D COUPE LIMTED'>2D COUPE LIMTED</option>
                <option value='4D SEDAN RALLIART'>4D SEDAN RALLIART</option>
                <option value='REG CAB 3.7L ST'>REG CAB 3.7L ST</option>
                <option value='EXT CAB 3.0L EDGE'>EXT CAB 3.0L EDGE</option>
                <option value='PASSENGER EXT 3.9L LT'>PASSENGER EXT 3.9L LT</option>
                <option value='4D SUV 5.3L FFV'>4D SUV 5.3L FFV</option>
                <option value='4D UTILITY 5.3L LS'>4D UTILITY 5.3L LS</option>
                <option value='CREW CAB 5.3L SLE'>CREW CAB 5.3L SLE</option>
                <option value='REG CAB 5.3L'>REG CAB 5.3L</option>
                <option value='4D UTILITY XUV 4.2L SLE'>4D UTILITY XUV 4.2L SLE</option>
                <option value='4D UTILITY 5.3L SLT'>4D UTILITY 5.3L SLT</option>
                <option value='4D SUV 4.6L'>4D SUV 4.6L</option>
                <option value='2D COUPE EX 5SP'>2D COUPE EX 5SP</option>
                <option value='5D HATCHBACK I'>5D HATCHBACK I</option>
                <option value='EXT CAB 2.8L LS'>EXT CAB 2.8L LS</option>
                <option value='REG CAB 3.7L SXT'>REG CAB 3.7L SXT</option>
                <option value='5D SEDAN S'>5D SEDAN S</option>
                <option value='2D SPYDER GTS'>2D SPYDER GTS</option>
                <option value='4D PASSENGER 4.2L LIMITED'>4D PASSENGER 4.2L LIMITED</option>
                <option value='4D WAGON S'>4D WAGON S</option>
                <option value='4D SUV 3.0L PREMIER'>4D SUV 3.0L PREMIER</option>
                <option value='2D COUPE GL1'>2D COUPE GL1</option>
                <option value='4D CUV DELUXE'>4D CUV DELUXE</option>
                <option value='4D SUV 5.7L HEMI SLT'>4D SUV 5.7L HEMI SLT</option>
                <option value='4D SEDAN ZX4 ST'>4D SEDAN ZX4 ST</option>
                <option value='4D CROSSOVER SEL'>4D CROSSOVER SEL</option>
                <option value='REG CAB 6.0L'>REG CAB 6.0L</option>
                <option value='4D SEDAN 2.4I'>4D SEDAN 2.4I</option>
                <option value='MINIVAN 3.8L LIMITED'>MINIVAN 3.8L LIMITED</option>
                <option value='4D SEDAN SEL AWD'>4D SEDAN SEL AWD</option>
                <option value='4D WAGON R/T'>4D WAGON R/T</option>
                <option value='3D EXT CAB 2.2L'>3D EXT CAB 2.2L</option>
                <option value='4D HATCHBACK ZX5 S'>4D HATCHBACK ZX5 S</option>
                <option value='4D SEDAN AWD SEL'>4D SEDAN AWD SEL</option>
                <option value='WAGON LX'>WAGON LX</option>
                <option value='4D WAGON LS'>4D WAGON LS</option>
                <option value='4D SEDAN XL'>4D SEDAN XL</option>
                <option value='4D SUV 4.0L EDDIE BAUER'>4D SUV 4.0L EDDIE BAUER</option>
                <option value='EXT CAB 4.2L XL'>EXT CAB 4.2L XL</option>
                <option value='4D SUV 2.4L'>4D SUV 2.4L</option>
                <option value='EXT CAB 3.9L SLT'>EXT CAB 3.9L SLT</option>
                <option value='4D SPORT UTILITY LIMITED FFV'>4D SPORT UTILITY LIMITED FFV</option>
                <option value='REG CAB 2.2L'>REG CAB 2.2L</option>
                <option value='4D SEDAN GTS'>4D SEDAN GTS</option>
                <option value='4D SEDAN 2.5 S'>4D SEDAN 2.5 S</option>
                <option value='QUAD CAB 4.7L ST'>QUAD CAB 4.7L ST</option>
                <option value='2D EXT CAB 3.0L'>2D EXT CAB 3.0L</option>
                <option value='4D SUV 5.3L LT'>4D SUV 5.3L LT</option>
                <option value='QUAD CAB 5.9L SLT'>QUAD CAB 5.9L SLT</option>
                <option value='EXT CAB 4.2L W/T'>EXT CAB 4.2L W/T</option>
                <option value='4D SUV 3.0L LUXURY'>4D SUV 3.0L LUXURY</option>
                <option value='REG CAB 4.8L'>REG CAB 4.8L</option>
                <option value='4D SUV 2.2L'>4D SUV 2.2L</option>
                <option value='2D HATCHBACK'>2D HATCHBACK</option>
                <option value='4D SEDAN 2.5 SL'>4D SEDAN 2.5 SL</option>
                <option value='4D SPORT UTILITY XSPORT'>4D SPORT UTILITY XSPORT</option>
                <option value='4D SEDAN DX'>4D SEDAN DX</option>
                <option value='4D HATCHBACK'>4D HATCHBACK</option>
                <option value='4D SEDAN SEL DURATEC'>4D SEDAN SEL DURATEC</option>
                <option value='REG CAB 4.6L XL'>REG CAB 4.6L XL</option>
                <option value='QUAD CAB 5.9L SPORT'>QUAD CAB 5.9L SPORT</option>
                <option value='EXT CAB 6.0L'>EXT CAB 6.0L</option>
                <option value='EXT CAB 5.6L LE'>EXT CAB 5.6L LE</option>
                <option value='4D UTILITY 5.3L FFV'>4D UTILITY 5.3L FFV</option>
                <option value='4D HARDTOP LX'>4D HARDTOP LX</option>
                <option value='CREW CAB 3.5L SL'>CREW CAB 3.5L SL</option>
                <option value='EXT CAB 4.8L SLE'>EXT CAB 4.8L SLE</option>
                <option value='4D SUV 2.3L CONVENIENCE'>4D SUV 2.3L CONVENIENCE</option>
                <option value='CREW CAB 6.0L LS'>CREW CAB 6.0L LS</option>
                <option value='REG CAB 5.7L SLT'>REG CAB 5.7L SLT</option>
                <option value='4D UTILITY 4.8L SLE'>4D UTILITY 4.8L SLE</option>
                <option value='REG CAB 5.4L XL'>REG CAB 5.4L XL</option>
                <option value='EXT CAB 4.0L LE'>EXT CAB 4.0L LE</option>
                <option value='EXT CAB 8.1L LS'>EXT CAB 8.1L LS</option>
                <option value='CREW CAB 4.3L LS'>CREW CAB 4.3L LS</option>
                <option value='REG CAB 4.3L LS'>REG CAB 4.3L LS</option>
                <option value='EXT CAB 3.5L'>EXT CAB 3.5L</option>
                <option value='REG CAB 4.3L SLE'>REG CAB 4.3L SLE</option>
                <option value='PASSENGER 3.9L LS'>PASSENGER 3.9L LS</option>
                <option value='CREW CAB 3.5L LS'>CREW CAB 3.5L LS</option>
                <option value='CREW CAB 4.7L SR5'>CREW CAB 4.7L SR5</option>
                <option value='4D SEDAN AUTO'>4D SEDAN AUTO</option>
                <option value='CREW CAB 3.5L Z71'>CREW CAB 3.5L Z71</option>
                <option value='CREW CAB 5.6L'>CREW CAB 5.6L</option>
                <option value='4D SUV 4.7L SL'>4D SUV 4.7L SL</option>
                <option value='EXT CAB 2.8L'>EXT CAB 2.8L</option>
                <option value='MINIVAN 3.8L ES'>MINIVAN 3.8L ES</option>
                <option value='4D SUV 5.7L HEMI LIMITED'>4D SUV 5.7L HEMI LIMITED</option>
                <option value='2D COUPE R/T'>2D COUPE R/T</option>
                <option value='REG CAB 5.3L LS'>REG CAB 5.3L LS</option>
                <option value='4D UTILITY 4.8L'>4D UTILITY 4.8L</option>
                <option value='REG CAB 3.5L SL'>REG CAB 3.5L SL</option>
                <option value='4D WAGON LAREDO FFV'>4D WAGON LAREDO FFV</option>
                <option value='4D SEDAN SS'>4D SEDAN SS</option>
                <option value='CREW CAB 5.6L LE'>CREW CAB 5.6L LE</option>
                <option value='CREW CAB 4.8L'>CREW CAB 4.8L</option>
                <option value='2D COUPE EX 6SP'>2D COUPE EX 6SP</option>
                <option value='4D SEDAN HYBRID'>4D SEDAN HYBRID</option>
                <option value='4D SEDAN GX'>4D SEDAN GX</option>
                <option value='4D SUV SPORT 2.4L'>4D SUV SPORT 2.4L</option>
                <option value='EXT CAB 3.7L SLT'>EXT CAB 3.7L SLT</option>
                <option value='MINIVAN EX-L'>MINIVAN EX-L</option>
                <option value='PASSENGER EXT 3.9L'>PASSENGER EXT 3.9L</option>
                <option value='2D SUV 4.0L SPORT XLS'>2D SUV 4.0L SPORT XLS</option>
                <option value='MAZDA5 GRAND TOURING'>MAZDA5 GRAND TOURING</option>
                <option value='4D WAGON ZX5'>4D WAGON ZX5</option>
                <option value='2D COUPE LX AUTO'>2D COUPE LX AUTO</option>
                <option value='2D COUPE RS'>2D COUPE RS</option>
                <option value='4D SEDAN LIMITED TURBO'>4D SEDAN LIMITED TURBO</option>
                <option value='4D SUV 4.7L LIMITED'>4D SUV 4.7L LIMITED</option>
                <option value='2D COUPE LX'>2D COUPE LX</option>
                <option value='4D SUV 5.4L'>4D SUV 5.4L</option>
                <option value='3D EXT CAB 4.3L'>3D EXT CAB 4.3L</option>
                <option value='REG CAB 4.7L FFV'>REG CAB 4.7L FFV</option>
                <option value='4D SEDAN R/T'>4D SEDAN R/T</option>
                <option value='4D WAGON GS'>4D WAGON GS</option>
                <option value='4D SPORT UTILITY 3.5L XLS'>4D SPORT UTILITY 3.5L XLS</option>
                <option value='4D SUV 4.0L FFV LIMITED'>4D SUV 4.0L FFV LIMITED</option>
                <option value='EXT CAB 5.3L SL'>EXT CAB 5.3L SL</option>
                <option value='4D UTILITY 4.8L SLT'>4D UTILITY 4.8L SLT</option>
                <option value='4D SUV 2.3L'>4D SUV 2.3L</option>
                <option value='ACCESS CAB 4.7L SR5'>ACCESS CAB 4.7L SR5</option>
                <option value='4D SEDAN SLE'>4D SEDAN SLE</option>
                <option value='5D HATCHBACK S'>5D HATCHBACK S</option>
                <option value='4D SEDAN Z24'>4D SEDAN Z24</option>
                <option value='WAGON DX'>WAGON DX</option>
                <option value='4D SEDAN AWD'>4D SEDAN AWD</option>
                <option value='2D HATCHBACK ZX3'>2D HATCHBACK ZX3</option>
                <option value='REG CAB 4.0L'>REG CAB 4.0L</option>
                <option value='4D WAGON OVERLAND'>4D WAGON OVERLAND</option>
                <option value='4D EXT CAB 3.0L EDGE'>4D EXT CAB 3.0L EDGE</option>
                <option value='EXT CAB 6.0L LS'>EXT CAB 6.0L LS</option>
                <option value='4D MINIVAN 3.4L VALUE'>4D MINIVAN 3.4L VALUE</option>
                <option value='4D SEDAN EX AUTO NAVIGATION'>4D SEDAN EX AUTO NAVIGATION</option>
                <option value='4D WAGON CONVENIENCE'>4D WAGON CONVENIENCE</option>
                <option value='4D SPORT UTILITY DX'>4D SPORT UTILITY DX</option>
                <option value='4D SUV 4.7L FFV SLT'>4D SUV 4.7L FFV SLT</option>
                <option value='4D HATCHBACK AWD'>4D HATCHBACK AWD</option>
                <option value='4D UTILITY 6.0L DENALI'>4D UTILITY 6.0L DENALI</option>
                <option value='DOUBLE CAB 4.7L SR5'>DOUBLE CAB 4.7L SR5</option>
                <option value='4D SEDAN XRS'>4D SEDAN XRS</option>
                <option value='3D COUPE SC2'>3D COUPE SC2</option>
                <option value='4D SEDAN FFV TOURING'>4D SEDAN FFV TOURING</option>
                <option value='4D SEDAN GS 3.0L FFV'>4D SEDAN GS 3.0L FFV</option>
                <option value='4D UTILITY 5.3L'>4D UTILITY 5.3L</option>
                <option value='4D WAGON GRAND TOURING'>4D WAGON GRAND TOURING</option>
                <option value='4D CUV GL'>4D CUV GL</option>
                <option value='4D PASSENGER 3.8L SEL LIMITED'>4D PASSENGER 3.8L SEL LIMITED</option>
                <option value='4D PASSENGER 3.8L SE SPORT'>4D PASSENGER 3.8L SE SPORT</option>
                <option value='EXT CAB 4.7L SR5'>EXT CAB 4.7L SR5</option>
                <option value='2D COUPE AUTO'>2D COUPE AUTO</option>
                <option value='2D COUPE LX 5SP'>2D COUPE LX 5SP</option>
                <option value='5D SEDAN ZX5'>5D SEDAN ZX5</option>
                <option value='CREW CAB 3.3L XE'>CREW CAB 3.3L XE</option>
                <option value='4D SPORT UTILITY XL7'>4D SPORT UTILITY XL7</option>
                <option value='4D WAGON SE DURATEC'>4D WAGON SE DURATEC</option>
                <option value='4D SEDAN SIGNATURE'>4D SEDAN SIGNATURE</option>
                <option value='4D SPORT UTILITY LIMITED'>4D SPORT UTILITY LIMITED</option>
                <option value='REG CAB 2.5L EDGE'>REG CAB 2.5L EDGE</option>
                <option value='QUAD CAB 4.7L FFV SLT'>QUAD CAB 4.7L FFV SLT</option>
                <option value='3D COUPE SC1'>3D COUPE SC1</option>
                <option value='4D SPORT UTILITY 3.5L XS'>4D SPORT UTILITY 3.5L XS</option>
                <option value='REG CAB 2.2L SL'>REG CAB 2.2L SL</option>
                <option value='EXT CAB 2.2L LS'>EXT CAB 2.2L LS</option>
                <option value='4D SPORT UTILITY LEVEL 3'>4D SPORT UTILITY LEVEL 3</option>
                <option value='2D HATCHBACK GS'>2D HATCHBACK GS</option>
                <option value='EXT CAB 4.6L LARIAT'>EXT CAB 4.6L LARIAT</option>
                <option value='4D SPORT UTILITY SL'>4D SPORT UTILITY SL</option>
                <option value='CREW CAB 4.6L LARIAT'>CREW CAB 4.6L LARIAT</option>
                <option value='4D SPORT UTILITY EX AUTO'>4D SPORT UTILITY EX AUTO</option>
                <option value='4D SEDAN HEMI'>4D SEDAN HEMI</option>
                <option value='4D WAGON SE COMFORT'>4D WAGON SE COMFORT</option>
                <option value='EXT CAB 3.5L Z71 LS'>EXT CAB 3.5L Z71 LS</option>
                <option value='4D HATCHBACK ZX5'>4D HATCHBACK ZX5</option>
                <option value='EXT CAB 3.7L SXT'>EXT CAB 3.7L SXT</option>
                <option value='2D ROADSTER'>2D ROADSTER</option>
                <option value='2D SPYDER GS'>2D SPYDER GS</option>
                <option value='4D SUV ULTRA'>4D SUV ULTRA</option>
                <option value='4D PASSENGER 4.2L SEL'>4D PASSENGER 4.2L SEL</option>
                <option value='2D HARTOP CONVERTIBLE GT'>2D HARTOP CONVERTIBLE GT</option>
                <option value='4D SEDAN VALUE AUTO'>4D SEDAN VALUE AUTO</option>
                <option value='4D SUV HARDTOP 2.5L ZR2'>4D SUV HARDTOP 2.5L ZR2</option>
                <option value='2D COUPE ZX2'>2D COUPE ZX2</option>
                <option value='QUAD CAB 3.9L SPORT'>QUAD CAB 3.9L SPORT</option>
                <option value='EXT CAB 3.0L SE'>EXT CAB 3.0L SE</option>
                <option value='PASSENGER EXT 3.4L WARNER BROS'>PASSENGER EXT 3.4L WARNER BROS</option>
                <option value='4D SUV LIMITED 2.4L'>4D SUV LIMITED 2.4L</option>
                <option value='EXT CAB 4.3L SL'>EXT CAB 4.3L SL</option>
                <option value='4D SEDAN ZX5'>4D SEDAN ZX5</option>
                <option value='2D COUPE GT PREMIUM'>2D COUPE GT PREMIUM</option>
                <option value='REG CAB 5.4L XLT'>REG CAB 5.4L XLT</option>
                <option value='MINIVAN 2.4L EC'>MINIVAN 2.4L EC</option>
                <option value='4D SUV HARDTOP 2.2L LT'>4D SUV HARDTOP 2.2L LT</option>
                <option value='QUAD CAB 5.9L'>QUAD CAB 5.9L</option>
                <option value='CREW CAB 4.8L LS'>CREW CAB 4.8L LS</option>
                <option value='2D LIFTBACK GT'>2D LIFTBACK GT</option>
                <option value='REG CAB 3.9L SXT'>REG CAB 3.9L SXT</option>
                <option value='4D SUV 4.6L LIMITED'>4D SUV 4.6L LIMITED</option>
                <option value='REG CAB 4.2L XLT'>REG CAB 4.2L XLT</option>
                <option value='2D COUPE SE1'>2D COUPE SE1</option>
                <option value='4D SEDAN L AWD'>4D SEDAN L AWD</option>
                <option value='EXT CAB 5.4L FX4'>EXT CAB 5.4L FX4</option>
                <option value='4D WAGON OUTBACK SPORT'>4D WAGON OUTBACK SPORT</option>
                <option value='2D CONVERTIBLE LIMITED'>2D CONVERTIBLE LIMITED</option>
                <option value='EXT CAB 2.4L SE'>EXT CAB 2.4L SE</option>
                <option value='MINIVAN 3.3L CARGO'>MINIVAN 3.3L CARGO</option>
                <option value='EXT CAB 2.5L'>EXT CAB 2.5L</option>
                <option value='4D SEDAN SX'>4D SEDAN SX</option>
                <option value='2D EXT CAB 3.0L XLT'>2D EXT CAB 3.0L XLT</option>
                <option value='CREW CAB 5.4L FFV FX4'>CREW CAB 5.4L FFV FX4</option>
                <option value='4D SUV SPORT 2.0L'>4D SUV SPORT 2.0L</option>
                <option value='4D SUV 2.2L PANEL SS'>4D SUV 2.2L PANEL SS</option>
                <option value='4D SPORT UTILITY X'>4D SPORT UTILITY X</option>
                <option value='REG CAB 2.5L'>REG CAB 2.5L</option>
                <option value='QUAD CAB 4.7L BIG HORN'>QUAD CAB 4.7L BIG HORN</option>
                <option value='CREW CAB 6.0L SLT'>CREW CAB 6.0L SLT</option>
                <option value='REG CAB 4.2L W/T'>REG CAB 4.2L W/T</option>
                <option value='QUAD CAB 4.7L FFV LONESTAR'>QUAD CAB 4.7L FFV LONESTAR</option>
                <option value='2D COUPE DX AUTO'>2D COUPE DX AUTO</option>
                <option value='4D SPORT UTILITY HYBRID LIMITED'>4D SPORT UTILITY HYBRID LIMITED</option>
                <option value='4D SUV 4.0L FFV EDDIE BAUER'>4D SUV 4.0L FFV EDDIE BAUER</option>
                <option value='PASSENGER EXT 3.4L LT'>PASSENGER EXT 3.4L LT</option>
                <option value='2D CONVERTIBLE LXI'>2D CONVERTIBLE LXI</option>
                <option value='2D SPORT UTILITY'>2D SPORT UTILITY</option>
                <option value='4D SEDAN 2.5L'>4D SEDAN 2.5L</option>
                <option value='4D SEDAN O-Z RALLY'>4D SEDAN O-Z RALLY</option>
                <option value='4D SUV 5.4L XLS'>4D SUV 5.4L XLS</option>
                <option value='5D MINIVAN LE'>5D MINIVAN LE</option>
                <option value='REG CAB 2.2L FFV SL'>REG CAB 2.2L FFV SL</option>
                <option value='2D COUPE LXI'>2D COUPE LXI</option>
                <option value='4D SEDAN OZ'>4D SEDAN OZ</option>
                <option value='REG CAB 2.3L XLT'>REG CAB 2.3L XLT</option>
                <option value='EXT CAB 4.2L XLT'>EXT CAB 4.2L XLT</option>
                <option value='4D WAGON CLASSIC'>4D WAGON CLASSIC</option>
                <option value='2D CONVERTIBLE GT'>2D CONVERTIBLE GT</option>
                <option value='EXT CAB 4.7L ST'>EXT CAB 4.7L ST</option>
                <option value='2D EXT CAB 3.0L SE'>2D EXT CAB 3.0L SE</option>
                <option value='4D CUV 3.5L GLS'>4D CUV 3.5L GLS</option>
                <option value='4D SEDAN SL'>4D SEDAN SL</option>
                <option value='4D WAGON SX'>4D WAGON SX</option>
                <option value='4D EXT CAB 3.0L XLT'>4D EXT CAB 3.0L XLT</option>
                <option value='5D SEDAN I'>5D SEDAN I</option>
                <option value='4D SEDAN LUXURY AWD'>4D SEDAN LUXURY AWD</option>
                <option value='4D SEDAN 2.5I'>4D SEDAN 2.5I</option>
                <option value='CREW CAB 3.3L'>CREW CAB 3.3L</option>
                <option value='2D COUPE ZX3 S'>2D COUPE ZX3 S</option>
                <option value='ACCESS CAB 4.0L SR5'>ACCESS CAB 4.0L SR5</option>
                <option value='REG CAB 5.4L W/T'>REG CAB 5.4L W/T</option>
                <option value='2D EXT CAB 2.3L XL'>2D EXT CAB 2.3L XL</option>
                <option value='CREW CAB 5.3L LT'>CREW CAB 5.3L LT</option>
                <option value='CARGO EXT 3.5L LT'>CARGO EXT 3.5L LT</option>
                <option value='4D SEDAN MAZDASPEED'>4D SEDAN MAZDASPEED</option>
                <option value='4D SEDAN TYPE S NAVIGATION'>4D SEDAN TYPE S NAVIGATION</option>
                <option value='4D EXT CAB 4.0L EDGE'>4D EXT CAB 4.0L EDGE</option>
                <option value='REG CAB 4.8L SLE'>REG CAB 4.8L SLE</option>
                <option value='MINIVAN 3.8L LX'>MINIVAN 3.8L LX</option>
                <option value='4D WAGON LIMITED HEMI'>4D WAGON LIMITED HEMI</option>
                <option value='4D WAGON L'>4D WAGON L</option>
                <option value='4D WAGON LUXURY'>4D WAGON LUXURY</option>
                <option value='4D SEDAN VP AUTO'>4D SEDAN VP AUTO</option>
                <option value='CREW CAB 4.6L KING RANCH'>CREW CAB 4.6L KING RANCH</option>
                <option value='2D CONVERTIBLE GL'>2D CONVERTIBLE GL</option>
                <option value='4D SEDAN XLE'>4D SEDAN XLE</option>
                <option value='EXT CAB 3.3L XE'>EXT CAB 3.3L XE</option>
                <option value='CREW CAB 5.4L XLT'>CREW CAB 5.4L XLT</option>
                <option value='EXT CAB 5.6L SE'>EXT CAB 5.6L SE</option>
                <option value='4D SEDAN 3.5L SXT'>4D SEDAN 3.5L SXT</option>
                <option value='4D WAGON ZXW'>4D WAGON ZXW</option>
                <option value='4D SEDAN CARTIER L'>4D SEDAN CARTIER L</option>
                <option value='CREW CAB 4.0L LE'>CREW CAB 4.0L LE</option>
                <option value='4D SUV 4.0L CONVENIENCE'>4D SUV 4.0L CONVENIENCE</option>
                <option value='4D HARDTOP JLS'>4D HARDTOP JLS</option>
                <option value='4D SPORT UTILITY 4XMOTION'>4D SPORT UTILITY 4XMOTION</option>
                <option value='4D EXT CAB 3.0L'>4D EXT CAB 3.0L</option>
                <option value='4D HATCHBACK ZX5 SES'>4D HATCHBACK ZX5 SES</option>
                <option value='4D CROSSOVER SE'>4D CROSSOVER SE</option>
                <option value='4D CUV 2.3L XLT'>4D CUV 2.3L XLT</option>
                <option value='CREW CAB LIMITED'>CREW CAB LIMITED</option>
                <option value='2D COUPE Z24'>2D COUPE Z24</option>
                <option value='4D SEDAN TYPE S'>4D SEDAN TYPE S</option>
                <option value='EXT CAB 3.9L SPORT'>EXT CAB 3.9L SPORT</option>
                <option value='4D SEDAN 2.5L PKG 2'>4D SEDAN 2.5L PKG 2</option>
                <option value='4D SUV 5.7L HEMI'>4D SUV 5.7L HEMI</option>
                <option value='MINIVAN 3.3L LXI'>MINIVAN 3.3L LXI</option>
                <option value='2D COUPE TYPE S'>2D COUPE TYPE S</option>
                <option value='2D CONVERTIBLE GLS'>2D CONVERTIBLE GLS</option>
                <option value='MINIVAN 3.3L FFV SXT'>MINIVAN 3.3L FFV SXT</option>
                <option value='EXT CAB 5.3L LT'>EXT CAB 5.3L LT</option>
                <option value='4D SPORT UTILITY LX AUTO'>4D SPORT UTILITY LX AUTO</option>
                <option value='4D SUV 6.2L LUXURY'>4D SUV 6.2L LUXURY</option>
                <option value='REG CAB 3.9L SPORT'>REG CAB 3.9L SPORT</option>
                <option value='4D WAGON FREEDOM'>4D WAGON FREEDOM</option>
                <option value='CREW CAB 5.4L FX4'>CREW CAB 5.4L FX4</option>
                <option value='EXT CAB 2.4L'>EXT CAB 2.4L</option>
                <option value='CREW CAB 3.5L'>CREW CAB 3.5L</option>
                <option value='4D SUV 5.3L FFV Z71'>4D SUV 5.3L FFV Z71</option>
                <option value='EXT CAB DURO CROSS 3.7L'>EXT CAB DURO CROSS 3.7L</option>
                <option value='4D UTILITY 5.3L FFV LT'>4D UTILITY 5.3L FFV LT</option>
                <option value='4D SEDAN SIGNATURE LTD'>4D SEDAN SIGNATURE LTD</option>
                <option value='CREW CAB 3.5L Z71 LS'>CREW CAB 3.5L Z71 LS</option>
                <option value='4D WAGON R/T AWD'>4D WAGON R/T AWD</option>
                <option value='DOUBLE CAB LS 3.7L'>DOUBLE CAB LS 3.7L</option>
                <option value='CREW CAB 6.0L'>CREW CAB 6.0L</option>
                <option value='4D SPORT UTILITY JLX'>4D SPORT UTILITY JLX</option>
                <option value='REG CAB 3.4L'>REG CAB 3.4L</option>
                <option value='4D SUV 5.9L R/T'>4D SUV 5.9L R/T</option>
                <option value='EXT CAB 3.9L SXT'>EXT CAB 3.9L SXT</option>
                <option value='4D SUV 6.0L LS'>4D SUV 6.0L LS</option>
                <option value='4D SPORT UTILITY SR5'>4D SPORT UTILITY SR5</option>
                <option value='EXT CAB 4D 5.2L LARAMIE SLT'>EXT CAB 4D 5.2L LARAMIE SLT</option>
                <option value='2D ROADSTER GXP'>2D ROADSTER GXP</option>
                <option value='4D SPORT UTILITY SE SUPERCHARGED'>4D SPORT UTILITY SE SUPERCHARGED</option>
                <option value='2D COUPE LTZ'>2D COUPE LTZ</option>
                <option value='4D UTILITY 4.2L SLT'>4D UTILITY 4.2L SLT</option>
                <option value='4D SUV 5.9L SLT PLUS'>4D SUV 5.9L SLT PLUS</option>
                <option value='2D COUPE GTS'>2D COUPE GTS</option>
                <option value='4D SEDAN VALUE PACKAGE AUTO'>4D SEDAN VALUE PACKAGE AUTO</option>
                <option value='CREW CAB 5.7L LIMITED'>CREW CAB 5.7L LIMITED</option>
                <option value='2D COUPE 5SP'>2D COUPE 5SP</option>
                <option value='4D SPORT UTILITY GRAND TOURING A'>4D SPORT UTILITY GRAND TOURING A</option>
                <option value='4D SEDAN EX 5SP'>4D SEDAN EX 5SP</option>
            <h3>What Is the color of the car ?</h3><br><select name="Color_encoded" id="Color_encoded" required="required">
                <option value='RED'>RED</option>
                <option value='WHITE'>WHITE</option>
                <option value='MAROON'>MAROON</option>
                <option value='SILVER'>SILVER</option>
                <option value='BLACK'>BLACK</option>
                <option value='GOLD'>GOLD</option>
                <option value='GREY'>GREY</option>
                <option value='BLUE'>BLUE</option>
                <option value='BEIGE'>BEIGE</option>
                <option value='PURPLE'>PURPLE</option>
                <option value='ORANGE'>ORANGE</option>
                <option value='GREEN'>GREEN</option>
                <option value='BROWN'>BROWN</option>
                <option value='YELLOW'>YELLOW</option>
                <option value='NOT AVAIL'>NOT AVAIL</option>
                <option value='OTHER'>OTHER</option>
            <h3>What Is the category of the car ?</h3><br><select name="Size_encoded" id="Size_encoded" required="required">
                <option value='MEDIUM'>MEDIUM</option>
                <option value='LARGE TRUCK'>LARGE TRUCK</option>
                <option value='COMPACT'>COMPACT</option>
                <option value='LARGE'>LARGE</option>
                <option value='VAN'>VAN</option>
                <option value='MEDIUM SUV'>MEDIUM SUV</option>
                <option value='LARGE SUV'>LARGE SUV</option>
                <option value='SPECIALTY'>SPECIALTY</option>
                <option value='SPORTS'>SPORTS</option>
                <option value='CROSSOVER'>CROSSOVER</option>
                <option value='SMALL SUV'>SMALL SUV</option>
                <option value='SMALL TRUCK'>SMALL TRUCK</option>
            <h3>from which auction provider are you buying the vehicule from ?</h3><br><select name="Auction_encoded" id="Size_encoded" required="required">
                <option value='ADESA'>ADESA</option>
                <option value='OTHER'>OTHER</option>
                <option value='MANHEIM'>MANHEIM</option>
            <h3>from which type of trim does the vehicule have ?</h3><br><select name="Auction_encoded" id="Size_encoded" required="required">
                <option value='ST'>ST</option>
                <option value='SXT'>SXT</option>
                <option value='ZX3'>ZX3</option>
                <option value='ES'>ES</option>
                <option value='EX'>EX</option>
                <option value='SE'>SE</option>
                <option value='SEL'>SEL</option>
                <option value='SLE'>SLE</option>
                <option value='XL'>XL</option>
                <option value='Bas'>Bas</option>
                <option value='LS'>LS</option>
            <h3>from which type of transmission does the vehicule have ?</h3><br><select name="Auction_encoded" id="Size_encoded" required="required">
                <option value='AUTO'>AUTO</option>
                <option value='MANUAL'>MANUAL</option>
            </select>
            <h3>Are you A Dealer or Individual</h3><br><select name="Seller_Type_Individual" id="resea" required="required">
                <option value="Dealer">Dealer</option>
                <option value="Individual">Individual</option>
            </select>
            <h3>Transmission type</h3><br><select name="Transmission_Mannual" id="research" required="required">
                <option value="Mannual">Manual Car</option>
                <option value="Automatic">Automatic Car</option>
            </select>
            <br><br><button id="sub" type="submit ">Calculate the Selling Price</button>
            <br>




        </form>



        <br><br><h3>{{ prediction_text }}<h3>
    </div>




    <style>
        body {
            background-color: lightslategray;
            text-align: center;
            padding: 0px;
        }
        
        #research {
            font-size: 18px;
            width: 100px;
            height: 23px;
            top: 23px;
        }
        
        #box {
            border-radius: 60px;
            border-color: 45px;
            border-style: solid;
            font-family: cursive;
            text-align: center;
            background-color: rgb(168, 131, 61);
            font-size: medium;
            position: absolute;
            width: 700px;
            bottom: 9%;
            height: 850px;
            right: 30%;
            padding: 0px;
            margin: 0px;
            font-size: 14px;
        }
        
        #fuel {
            width: 83px;
            height: 43px;
            text-align: center;
            border-radius: 14px;
            font-size: 20px;
        }
        
        #fuel:hover {
            background-color: coral;
        }
        
        #research {
            width: 99px;
            height: 43px;
            text-align: center;
            border-radius: 14px;
            font-size: 18px;
        }
        
        #research:hover {
            background-color: coral;
        }
        
        #resea {
            width: 99px;
            height: 43px;
            text-align: center;
            border-radius: 14px;
            font-size: 18px;
        }
        
        #resea:hover {
            background-color: coral;
        }
        
        #sub {
            width: 120px;
            height: 43px;
            text-align: center;
            border-radius: 14px;
            font-size: 18px;
        }
        
        #sub:hover {
            background-color: darkcyan;
        }
        
        #first {
            border-radius: 14px;
            height: 25px;
            font-size: 20px;
            text-align: center;
        }
        
        #second {
            border-radius: 14px;
            height: 25px;
            font-size: 20px;
            text-align: center;
        }
        
        #third {
            border-radius: 14px;
            height: 25px;
            font-size: 20px;
            text-align: center;
        }
        
        #fourth {
            border-radius: 14px;
            height: 25px;
            font-size: 20px;
            text-align: center;
        }
    </style>
</body>

</html>

# %%
from flask import Flask, render_template, request
import jsonify
import requests
import pickle
import numpy as np
import sklearn
from sklearn.preprocessing import StandardScaler
app = Flask(__name__)
model = pickle.load(open('random_forest_regression_model.pkl', 'rb'))
@app.route('/',methods=['GET'])
def Home():
    return render_template('index.html')


standard_to = StandardScaler()
@app.route("/predict", methods=['POST'])
def predict():
    Fuel_Type_Diesel=0
    if request.method == 'POST':
        Year = int(request.form['Year'])
        Present_Price=float(request.form['Present_Price'])
        Kms_Driven=int(request.form['Kms_Driven'])
        Kms_Driven2=np.log(Kms_Driven)
        Owner=int(request.form['Owner'])
        Fuel_Type_Petrol=request.form['Fuel_Type_Petrol']
        if(Fuel_Type_Petrol=='Petrol'):
                Fuel_Type_Petrol=1
                Fuel_Type_Diesel=0
        else:
            Fuel_Type_Petrol=0
            Fuel_Type_Diesel=1
        Year=2020-Year
        Seller_Type_Individual=request.form['Seller_Type_Individual']
        if(Seller_Type_Individual=='Individual'):
            Seller_Type_Individual=1
        else:
            Seller_Type_Individual=0	
        Transmission_Mannual=request.form['Transmission_Mannual']
        if(Transmission_Mannual=='Mannual'):
            Transmission_Mannual=1
        else:
            Transmission_Mannual=0
        prediction=model.predict([[Present_Price,Kms_Driven2,Owner,Year,Fuel_Type_Diesel,Fuel_Type_Petrol,Seller_Type_Individual,Transmission_Mannual]])
        output=round(prediction[0],2)
        if output<0:
            return render_template('index.html',prediction_texts="Sorry you cannot sell this car")
        else:
            return render_template('index.html',prediction_text="You Can Sell The Car at {}".format(output))
    else:
        return render_template('index.html')

if __name__=="__main__":
    app.run(debug=True)
